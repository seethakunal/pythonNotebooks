# %% [markdown]
# ## Information Retrieval using Boolean Model
#
# * Generate document.txt (using the sample document.txt provided). Input the list of documents and terms in each document
# * Specify the query terms to retrieve the most relevant document(s) that match the query.
# * Report the results of the IR using Boolean Model. The results are saved in the output file (output_boolean.txt)

# %%
# Kunal Seetha

# %%
import pandas
# module to read the contents of the file from a csv file

from contextlib import redirect_stdout
# module to redirect the output to a text file

terms = []
# list to store the terms present in the documents

keys = []
# list to store the names of the documents

vec_Dic = {}
# dictionary to store the name of the document and the boolean vector as list

dicti = {}
# dictionary to store the name of the document and the terms present in it as a
# vector

dummy_List = []
# list for performing some operations and clearing them

def filter(documents, rows, cols):
	'''function to read and separate the name of the documents and the terms
  present in it to a separate list from the data frame and also create a
  dictionary which has the name of the document as key and the terms present in
  it as the list of strings which is the value of the key'''

	for i in range(rows):
		for j in range(cols):
		  # traversal through the data frame

			if(j == 0):
        # first column has the name of the document in the csv file
				keys.append(documents.loc[i].iat[j])
			else:
				dummy_List.append(documents.loc[i].iat[j])
			  # dummy list to update the terms in the dictionary

			if documents.loc[i].iat[j] not in terms:
				# add the terms to the list if it is not present else continue
				terms.append(documents.loc[i].iat[j])

		copy = dummy_List.copy()
    # copying the dummy list to a different list

		dicti.update({documents.loc[i].iat[0]: copy})
		print(dicti)
		# adding the key value pair to a dictionary

		dummy_List.clear()
		# clearing the dummy list

def bool_Representation(dicti, rows, cols):
  '''In this function we get a boolean representation of the terms present in the
  documents in the form of lists, later we create a dictionary which contains
  the name of the documents as key and value as the list of boolean values
  representing the terms present in the document'''

  #terms.sort()
	# we sort the elements in the alphabetical order for the convience, the order
	# of the term does not make any difference

  for i in (dicti):
		# for every document in the dictionary we check for each string present in
		# the list

    for j in terms:
			# if the string is present in the list we append 1 else we append 0

      if j in dicti[i]:
        dummy_List.append(1)
      else:
        dummy_List.append(0)
			# appending 1 or 0 for obtaining the boolean representation

    copy = dummy_List.copy()
		# copying the dummy list to a different list

    vec_Dic.update({i: copy})
		# adding the key value pair to a dictionary

    dummy_List.clear()
		# clearing the dummy list

def query_Vector(query):
  '''In this function we represent the query in the form of boolean vector'''

  qvect = []
  # query vector which is returned at the end of the function

  print(terms)
  for i in terms:
	  # if the word present in the list of terms is also present in the query
	  # then append 1 else append 0
    if i in query:
      qvect.append(1)
    else:
      qvect.append(0)

  return qvect
  # return the query vector which is obtained in the boolean form

def prediction(q_Vect):
	'''In this function we make the prediction regarding which document is related
	to the given query by performing the boolean operations'''

	dictionary = {}
	listi = []
	count = 0
	# initialisation of the dictionary , list and a variable which is further
	# required for performing the computation

	term_Len = len(terms)
	# number of terms present in the term list

	for i in vec_Dic:
		# for every document in the dictionary containing the terms present in it
		# the form of boolean vector

		for t in range(term_Len):
			if(q_Vect[t] == vec_Dic[i][t]):
				# if the words present in the query is also present in the
				# document or if the words present in the query is also absent in
				# the document

				count += 1
				# increase the value of count variable by one
				# the condition in which words present in document and absent in
				#query , present in query and absent in document is not considered

		dictionary.update({i: count})
		# dictionary updation here the name of the document is the key and the
		# count variable computed earlier is the value

		count = 0
		# reinitialisaion of count variable to 0

	for i in dictionary:
		listi.append(dictionary[i])
		# here we append the count value to list

	listi = sorted(listi, reverse=True)
	# we sort the list in the descending order which is needed to rank the
	#documents according to the relevance

	ans = ' '
	# variable to store the name of the document which is most relevant

	with open('output_boolean.txt', 'w') as f:
		with redirect_stdout(f):
			# to redirect the output to a text file

			print("ranking of the documents")

			for count, i in enumerate(listi):
				key = check(dictionary, i)
				# Function call to get the key when the value is known
				if count == 0:
					ans = key
					# to store the name of the document which is most relevant

				print(key, "rank is", count+1)
				# print the name of the document along with its rank

				dictionary.pop(key)
				# remove the key from the dictionary after printing

			print(ans, "is the most relevant document for the given query")
			# to print the name of the document which is most relevant

def check(dictionary, val):
	'''Function to return the key when the value is known'''

	for key, value in dictionary.items():
		if(val == value):
			# if the given value is same as the value present in the dictionary
			# return the key

			return key

def main():
  documents = pandas.read_csv('/mnt/home/kxs997/Downloads/document.txt', sep=" ") #, on_bad_lines="skip")
	# create your list of documents and the terms in each document (as given in the sample documents.txt file)

  print(documents)
	# to read the data from the csv file as a dataframe

  rows = len(documents)
  #print("Rows: " + str(rows))
	# to get the number of rows

  cols = len(documents.columns)
  # print("Cols: " + str(cols))
	# to get the number of columns

  filter(documents, rows, cols)
	# function call to read and separate the name of the documents and the terms
	# present in it to a separate list from the data frame and also create a
	# dictionary which has the name of the document as key and the terms present in
	# it as the list of strings which is the value of the key

  bool_Representation(dicti, rows, cols)
	# In this function we get a boolean representation of the terms present in the
	# documents in the form of lists, later we create a dictionary which contains
	# the name of the documents as key and value as the list of boolean values
	#representing the terms present in the document

  print("Enter query")
  query = input()
	# to get the query input from the user, the below input is given for obtaining
	# the output as in output.txt file
	# hockey is a national sport

  query = query.split(' ')
  #print(query)
	# splitting the query as a list of strings

  q_Vect = query_Vector(query)
  #print(q_Vect)
	# function call to represent the query in the form of boolean vector

  prediction(q_Vect)
	# Function call to make the prediction regarding which document is related to
	# the given query by performing the boolean operations

main()
# Out:
#      Document        term1        term2       term3
# 0  Document-1  Information       theory    practice
# 1  Document-2  Information    retrieval     systems
# 2  Document-3       Modern  information   retrieval
# 3  Document-4         Text  Compression  techniques
# {'Document-1': ['Information', 'theory', 'practice']}
# {'Document-1': ['Information', 'theory', 'practice'], 'Document-2': ['Information', 'retrieval', 'systems']}
# {'Document-1': ['Information', 'theory', 'practice'], 'Document-2': ['Information', 'retrieval', 'systems'], 'Document-3': ['Modern', 'information', 'retrieval']}
# {'Document-1': ['Information', 'theory', 'practice'], 'Document-2': ['Information', 'retrieval', 'systems'], 'Document-3': ['Modern', 'information', 'retrieval'], 'Document-4': ['Text', 'Compression', 'techniques']}
# Enter query
#  ggg
# ['Document-1', 'Information', 'theory', 'practice', 'Document-2', 'retrieval', 'systems', 'Document-3', 'Modern', 'information', 'Document-4', 'Text', 'Compression', 'techniques']

# %% [markdown]
# ## Information Retrieval using Vector Space Model
#
# * Use the VSM Model to run your query on your document.txt file
# * Compare the output of VSM and Boolean Model. Explain the observed result. The resuls are saved in the output file (output_vsm.txt)

# %%
# implementation of vector space model for document retrieval

import pandas
# module to read the contents of the file from a csv file

from contextlib import redirect_stdout
# module to redirect the output to a text file

import math
# module to perform mathematical functions

terms = []
# list to store the terms present in the documents

keys = []
# list to store the names of the documents

vec_Dic = {}
# dictionary to store the name of the document and the weight as list

dicti = {}
# dictionary to store the name of the document and the terms present in it as a
# vector

dummy_List = []
# list for performing some operations and clearing them

term_Freq = {}
# dictionary to store the term and the number of times of its occurrence in the
# documents

idf = {}
# dictionary to store the term and the inverse document frequency

weight = {}
# dictionary to store the term and the weight which is the product of term
# frequency and inverse document frequency


def filter(documents, rows, cols):
  '''function to read and separate the name of the documents and the terms
  present in it to a separate list from the data frame and also create a
  dictionary which has the name of the document as key and the terms present
  in it as the list of strings which is the value of the key'''

  for i in range(rows):
    for j in range(cols):
      # traversal through the data frame

      if(j == 0):
        # first column has the name of the document in the csv file
        keys.append(documents.loc[i].iat[j])
      else:
        dummy_List.append(documents.loc[i].iat[j])
        # dummy list to update the terms in the dictionary

        if documents.loc[i].iat[j] not in terms:
          # add the terms to the list if it is not present else continue
          terms.append(documents.loc[i].iat[j])

    copy = dummy_List.copy()
    # copying the dummy list to a different list

    dicti.update({documents.loc[i].iat[0]: copy})
    # adding the key value pair to a dictionary

    dummy_List.clear()
    # clearing the dummy list


def compute_Weight(doc_Count, cols):
  '''Function to compute the weight for each of the terms in the document.
  Here the weight is calculated with the help of term frequency and
  inverse document frequency'''

  for i in terms:
    # initially adding all the elements into the dictionary and initialising
    # the values as zero
    if i not in term_Freq:
      term_Freq.update({i: 0})

  for key, value in dicti.items():
    # to get the number of occurrence of each terms
    for k in value:
      if k in term_Freq:
        term_Freq[k] += 1
        # value incremented by one if the term is found in the documents

  idf = term_Freq.copy()
  # copying the term frequency dictionary to a dictionary named idf which is
  # further neede for computation

  for i in term_Freq:
    term_Freq[i] = term_Freq[i]/cols
    # term frequency is number of occurrence divided by total number of
    # documents

  for i in idf:
    if idf[i] != doc_Count:
      idf[i] = math.log2(cols / idf[i])
      # inverse document frequency log of total number of documents divided
      # by number of occurrence of the terms
    else:
      idf[i] = 0
      # this is to avoid the zero division error

  for i in idf:
    weight.update({i: idf[i]*term_Freq[i]})
    # weight is the product of term frequency and the inverse document
    # frequency

  for i in dicti:
    for j in dicti[i]:
      dummy_List.append(weight[j])

    copy = dummy_List.copy()
    vec_Dic.update({i: copy})
    dummy_List.clear()
    # above operations performed to get the dictionary of weighted vector
    # for each of the documents


def get_Weight_For_Query(query):
  '''function to get the weight for each terms present in the query, here we
  consider the term frequency as the weight of the terms'''

  query_Freq = {}
  # initialisation of the dictionary with query terms as key and its weight as
  # the values

  for i in terms:
    # initially adding all the elements into the dictionary and initialising
    # the values as zero
    if i not in query_Freq:
      query_Freq.update({i: 0})

  for val in query:
    # to get the number of occurrence of each terms
    if val in query_Freq:
      query_Freq[val] += 1
      # value incremented by one if the term is found in the documents

  for i in query_Freq:
    query_Freq[i] = query_Freq[i] / len(query)
    # term frequency obtained by dividing the number of occurrence of terms by
    # total number of terms in the query

  return query_Freq
  # return the dictionary in which the key is the term and the value is the
  # weight


def similarity_Computation(query_Weight):
  ''' Function to calculate the similarity measure in which the weight of the
  query and the document is multiplied in the numerator and the weight is
  squared and squareroot is taken the weights of the query and document'''

  numerator = 0
  denomi1 = 0
  denomi2 = 0
  # initialisation of the variables with zero which is needed for computation

  similarity = {}
  # initialisation of dictionary which has the name of document as key and the
  # similarity measure as value

  for document in dicti:
    for terms in dicti[document]:
      # cosine similarity is calculated

      numerator += weight[terms] * query_Weight[terms]
      denomi1 += weight[terms] * weight[terms]
      denomi2 += query_Weight[terms] * query_Weight[terms]
      # print(str(weight[terms]) + " " + str(query_Weight[terms]) + " " + str(numerator) + " " + str(denomi1) + " " + str(denomi2) )
      # the summation values of the weight is calculated and later they are
      # divided

    if denomi1 != 0 and denomi2 != 0:
      # to avoid the zero division error

      simi = numerator / (math.sqrt(denomi1) * math.sqrt(denomi2))
      similarity.update({document: simi})
      #dictionary is updated

      numerator = 0
      denomi2 = 0
      denomi1 = 0
      # reinitialisation of the variables to zero
    else:
      similarity.update({document: 0})

  return (similarity)
  # the dictionary containing similarity measure as the value


def prediction(similarity, doc_count):
  '''Function to predict the document which is relevant to the query '''

  ranked_sim = sorted(similarity.items(), key=lambda x: x[1], reverse=True)

  with open('output_vsm.txt', 'w') as f:
    with redirect_stdout(f):
      # to redirect the output to a text file

      ans = max(similarity, key=similarity.get)
      print(ans, "is the most relevant document")
      # to print the name of the document which is most relevant

      print("ranking of the documents")
      for i in range(doc_count):
 #       ans = max(similarity, key=lambda x: similarity[x])
        print(list(ranked_sim)[i], "rank is", i+1)
      # to print the document name and its rank

      similarity.pop(ans)


def main():
  documents = pandas.read_csv('/mnt/home/kxs997/Downloads/document.txt', sep=" ")
  # to read the data from the csv file as a dataframe

  rows = len(documents)
  # to get the number of rows

  cols = len(documents.columns)
  # to get the number of columns

  filter(documents, rows, cols)
  # function call to read and separate the name of the documents and the terms
  # present in it to a separate list from the data frame and also create a
  # dictionary which has the name of the document as key and the terms present
  # in it as the list of strings which is the value of the key

  compute_Weight(rows, cols)
  # Function to compute the weight for each of the terms in the document.
  # Here the weight is calculated with the help of term frequency and inverse
  # document frequency

  print("Enter the query")
  query = input()
  # to get the query input from the user, the below input is given for obtaining
  # the output as in output.txt file
  # one three three

  query = query.split(' ')
  # splitting the query as a list of strings

  query_Weight = get_Weight_For_Query(query)
  # function call to get the weight for each terms present in the query, here we
  # consider the term frequency as the weight of the terms'''

  similarity = similarity_Computation(query_Weight)
  # Function call to calculate the similarity measure in which the weight of the
  # query and the document is multiplied in the numerator and the weight is
  # squared and squareroot is taken the weights of the query and document

  prediction(similarity, rows)
  # Function call to predict the document which is relevant to the query

main()
# Out:
# Enter the query
#  ggg

# %%
# part 2

import pandas as pd
from bs4 import BeautifulSoup
import urllib.request

# url, and fetch html content
url = "https://bulletin.case.edu/course-descriptions/csds/"
html = urllib.request.urlopen(url).read()

# Parse the HTML with BeautifulSoup
soup = BeautifulSoup(html, 'lxml')

# Find all course blocks in the right column
courses = soup.find("div", {"id": "right-col"}).find_all("div", {"class": "courseblock"})

# List to store course details
course_details = []

# Extract information for each course
for course in courses:
    title = str(course.find('p', {"class": "courseblocktitle"}).text).strip()
    details = title.split(".")
    course_id, course_name, credits = details[0].strip(), details[1].strip(), details[2].strip()

    # Extracting course name and course description
    description = str(course.find('p', {"class": "courseblockdesc"}).text).strip()

    # Append course details to the list
    course_details.append({
        'Course ID': course_id,
        'Course Name': course_name,
        'Credits': credits,
        'Description': description
    })

# Create a Pandas DataFrame from the list
df = pd.DataFrame(course_details)

# Print and save the DataFrame to a CSV file
print(df)
df.to_csv('course_details.csv', index=False)
# Out:
#     Course ID                                        Course Name  \
# 0    CSDS 101  The Digital Revolution: Computer and Data Scie...
# 1    CSDS 132                                Programming in Java
# 2    CSDS 133  Introduction to Data Science and Engineering f...
# 3    CSDS 221                         Full Stack Web Development
# 4    CSDS 233                    Introduction to Data Structures
# ..        ...                                                ...
# 98   CSDS 620                                     Special Topics
# 99   CSDS 621                                   Special Projects
# 100  CSDS 651                                           Thesis M
# 101  CSDS 695                                          Project M
# 102  CSDS 701                                    Dissertation Ph
#
#           Credits                                        Description
# 0         4 Units  For students who want to explore the history, ...
# 1         3 Units  An in-depth survey of modern programming langu...
# 2         3 Units  This course is an introduction to data science...
# 3         4 Units  An introduction to full stack web development,...
# 4         4 Units  Different representations of data: lists, stac...
# ..            ...                                                ...
# 98   1 - 18 Units
# 99   1 - 18 Units
# 100             S                                Credit as arranged.
# 101             S  Research course taken by Plan B M.S. students....
# 102             D  Credit as arranged.\nPrereq: Predoctoral resea...
#
# [103 rows x 4 columns]

# %%
# !pip install scrapy
# Out:
# Requirement already satisfied: scrapy in /mnt/home/kxs997/anaconda3/lib/python3.11/site-packages (2.8.0)
# Requirement already satisfied: Twisted>=18.9.0 in /mnt/home/kxs997/anaconda3/lib/python3.11/site-packages (from scrapy) (22.10.0)
# Requirement already satisfied: cryptography>=3.4.6 in /mnt/home/kxs997/anaconda3/lib/python3.11/site-packages (from scrapy) (39.0.1)
# Requirement already satisfied: cssselect>=0.9.1 in /mnt/home/kxs997/anaconda3/lib/python3.11/site-packages (from scrapy) (1.1.0)
# Requirement already satisfied: itemloaders>=1.0.1 in /mnt/home/kxs997/anaconda3/lib/python3.11/site-packages (from scrapy) (1.0.4)
# Requirement already satisfied: parsel>=1.5.0 in /mnt/home/kxs997/anaconda3/lib/python3.11/site-packages (from scrapy) (1.6.0)
# Requirement already satisfied: pyOpenSSL>=21.0.0 in /mnt/home/kxs997/anaconda3/lib/python3.11/site-packages (from scrapy) (23.0.0)
# Requirement already satisfied: queuelib>=1.4.2 in /mnt/home/kxs997/anaconda3/lib/python3.11/site-packages (from scrapy) (1.5.0)
# Requirement already satisfied: service-identity>=18.1.0 in /mnt/home/kxs997/anaconda3/lib/python3.11/site-packages (from scrapy) (18.1.0)
# Requirement already satisfied: w3lib>=1.17.0 in /mnt/home/kxs997/anaconda3/lib/python3.11/site-packages (from scrapy) (1.21.0)
# Requirement already satisfied: zope.interface>=5.1.0 in /mnt/home/kxs997/anaconda3/lib/python3.11/site-packages (from scrapy) (5.4.0)
# Requirement already satisfied: protego>=0.1.15 in /mnt/home/kxs997/anaconda3/lib/python3.11/site-packages (from scrapy) (0.1.16)
# Requirement already satisfied: itemadapter>=0.1.0 in /mnt/home/kxs997/anaconda3/lib/python3.11/site-packages (from scrapy) (0.3.0)
# Requirement already satisfied: setuptools in /mnt/home/kxs997/anaconda3/lib/python3.11/site-packages (from scrapy) (67.8.0)
# Requirement already satisfied: packaging in /mnt/home/kxs997/anaconda3/lib/python3.11/site-packages (from scrapy) (23.0)
# Requirement already satisfied: tldextract in /mnt/home/kxs997/anaconda3/lib/python3.11/site-packages (from scrapy) (3.2.0)
# Requirement already satisfied: lxml>=4.3.0 in /mnt/home/kxs997/anaconda3/lib/python3.11/site-packages (from scrapy) (4.9.1)
# Requirement already satisfied: PyDispatcher>=2.0.5 in /mnt/home/kxs997/anaconda3/lib/python3.11/site-packages (from scrapy) (2.0.5)
# Requirement already satisfied: cffi>=1.12 in /mnt/home/kxs997/anaconda3/lib/python3.11/site-packages (from cryptography>=3.4.6->scrapy) (1.15.1)
# Requirement already satisfied: jmespath>=0.9.5 in /mnt/home/kxs997/anaconda3/lib/python3.11/site-packages (from itemloaders>=1.0.1->scrapy) (0.10.0)
# Requirement already satisfied: six>=1.6.0 in /mnt/home/kxs997/anaconda3/lib/python3.11/site-packages (from parsel>=1.5.0->scrapy) (1.16.0)
# Requirement already satisfied: attrs>=16.0.0 in /mnt/home/kxs997/anaconda3/lib/python3.11/site-packages (from service-identity>=18.1.0->scrapy) (22.1.0)
# Requirement already satisfied: pyasn1-modules in /mnt/home/kxs997/anaconda3/lib/python3.11/site-packages (from service-identity>=18.1.0->scrapy) (0.2.8)
# Requirement already satisfied: pyasn1 in /mnt/home/kxs997/anaconda3/lib/python3.11/site-packages (from service-identity>=18.1.0->scrapy) (0.4.8)
# Requirement already satisfied: constantly>=15.1 in /mnt/home/kxs997/anaconda3/lib/python3.11/site-packages (from Twisted>=18.9.0->scrapy) (15.1.0)
# Requirement already satisfied: incremental>=21.3.0 in /mnt/home/kxs997/anaconda3/lib/python3.11/site-packages (from Twisted>=18.9.0->scrapy) (21.3.0)
# Requirement already satisfied: Automat>=0.8.0 in /mnt/home/kxs997/anaconda3/lib/python3.11/site-packages (from Twisted>=18.9.0->scrapy) (20.2.0)
# Requirement already satisfied: hyperlink>=17.1.1 in /mnt/home/kxs997/anaconda3/lib/python3.11/site-packages (from Twisted>=18.9.0->scrapy) (21.0.0)
# Requirement already satisfied: typing-extensions>=3.6.5 in /mnt/home/kxs997/anaconda3/lib/python3.11/site-packages (from Twisted>=18.9.0->scrapy) (4.6.3)
# Requirement already satisfied: idna in /mnt/home/kxs997/anaconda3/lib/python3.11/site-packages (from tldextract->scrapy) (3.4)
# Requirement already satisfied: requests>=2.1.0 in /mnt/home/kxs997/anaconda3/lib/python3.11/site-packages (from tldextract->scrapy) (2.29.0)
# Requirement already satisfied: requests-file>=1.4 in /mnt/home/kxs997/anaconda3/lib/python3.11/site-packages (from tldextract->scrapy) (1.5.1)
# Requirement already satisfied: filelock>=3.0.8 in /mnt/home/kxs997/anaconda3/lib/python3.11/site-packages (from tldextract->scrapy) (3.9.0)
# Requirement already satisfied: pycparser in /mnt/home/kxs997/anaconda3/lib/python3.11/site-packages (from cffi>=1.12->cryptography>=3.4.6->scrapy) (2.21)
# Requirement already satisfied: charset-normalizer<4,>=2 in /mnt/home/kxs997/anaconda3/lib/python3.11/site-packages (from requests>=2.1.0->tldextract->scrapy) (2.0.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /mnt/home/kxs997/anaconda3/lib/python3.11/site-packages (from requests>=2.1.0->tldextract->scrapy) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in /mnt/home/kxs997/anaconda3/lib/python3.11/site-packages (from requests>=2.1.0->tldextract->scrapy) (2023.7.22)

# %%
import scrapy
import pandas as pd
from scrapy.crawler import CrawlerProcess


class BookRatings(scrapy.Spider):
    name = "BookRatings"
    allowed_domains = ['books.toscrape.com']
    start_urls = ['http://books.toscrape.com/catalogue/category/books/travel_2/index.html',
                  'http://books.toscrape.com/catalogue/category/books/mystery_3/index.html',
                  'http://books.toscrape.com/catalogue/category/books/historical-fiction_4/index.html',
                  'http://books.toscrape.com/catalogue/category/books/sequential-art_5/index.html',
                  'http://books.toscrape.com/catalogue/category/books/classics_6/index.html',
                  'http://books.toscrape.com/catalogue/category/books/philosophy_7/index.html',
                  'http://books.toscrape.com/catalogue/category/books/romance_8/index.html',
                  'http://books.toscrape.com/catalogue/category/books/womens-fiction_9/index.html',
                  'http://books.toscrape.com/catalogue/category/books/fiction_10/index.html']
    
    def parse(self, response):
        books = []
        for book in response.css('ol.row li'):
            rating = book.css('p[class^="star-rating"]::attr(class)').get().split('-')[-1].split('rating')[1].strip()
            book_name = book.css('h3 a::text').get()
            books.append({
                'Book': book_name, 
                'Rating': rating
            })
        df = pd.DataFrame(books)
        print(df)
"""
def save_to_csv(result, output_file='books.csv'):
    combined_df = pd.concat(result, ignore_index=True)
    combined_df.to_csv(output_file, index=False)
    print("data saved to csv")
"""


process = CrawlerProcess()
process.crawl(BookRatings)
process.start()
# Out:
# 2023-11-14 11:09:41 [scrapy.utils.log] INFO: Scrapy 2.8.0 started (bot: scrapybot)
# 2023-11-14 11:09:41 [scrapy.utils.log] INFO: Versions: lxml 4.9.1.0, libxml2 2.9.14, cssselect 1.1.0, parsel 1.6.0, w3lib 1.21.0, Twisted 22.10.0, Python 3.11.3 (main, Apr 19 2023, 23:54:32) [GCC 11.2.0], pyOpenSSL 23.0.0 (OpenSSL 1.1.1w  11 Sep 2023), cryptography 39.0.1, Platform Linux-5.15.0-86-generic-x86_64-with-glibc2.31
# 2023-11-14 11:09:41 [scrapy.crawler] INFO: Overridden settings:
# {}
# 2023-11-14 11:09:41 [py.warnings] WARNING: /mnt/home/kxs997/anaconda3/lib/python3.11/site-packages/scrapy/utils/request.py:232: ScrapyDeprecationWarning: '2.6' is a deprecated value for the 'REQUEST_FINGERPRINTER_IMPLEMENTATION' setting.
#
# It is also the default value. In other words, it is normal to get this warning if you have not defined a value for the 'REQUEST_FINGERPRINTER_IMPLEMENTATION' setting. This is so for backward compatibility reasons, but it will change in a future version of Scrapy.
#
# See the documentation of the 'REQUEST_FINGERPRINTER_IMPLEMENTATION' setting for information on how to handle this deprecation.
#   return cls(crawler)
#
# 2023-11-14 11:09:41 [scrapy.utils.log] DEBUG: Using reactor: twisted.internet.epollreactor.EPollReactor
# 2023-11-14 11:09:41 [scrapy.extensions.telnet] INFO: Telnet Password: 1847db9340f060bd
# 2023-11-14 11:09:41 [scrapy.middleware] INFO: Enabled extensions:
# ['scrapy.extensions.corestats.CoreStats',
#  'scrapy.extensions.telnet.TelnetConsole',
#  'scrapy.extensions.memusage.MemoryUsage',
#  'scrapy.extensions.logstats.LogStats']
# 2023-11-14 11:09:41 [scrapy.middleware] INFO: Enabled downloader middlewares:
# ['scrapy.downloadermiddlewares.httpauth.HttpAuthMiddleware',
#  'scrapy.downloadermiddlewares.downloadtimeout.DownloadTimeoutMiddleware',
#  'scrapy.downloadermiddlewares.defaultheaders.DefaultHeadersMiddleware',
#  'scrapy.downloadermiddlewares.useragent.UserAgentMiddleware',
#  'scrapy.downloadermiddlewares.retry.RetryMiddleware',
#  'scrapy.downloadermiddlewares.redirect.MetaRefreshMiddleware',
#  'scrapy.downloadermiddlewares.httpcompression.HttpCompressionMiddleware',
#  'scrapy.downloadermiddlewares.redirect.RedirectMiddleware',
#  'scrapy.downloadermiddlewares.cookies.CookiesMiddleware',
#  'scrapy.downloadermiddlewares.httpproxy.HttpProxyMiddleware',
#  'scrapy.downloadermiddlewares.stats.DownloaderStats']
# 2023-11-14 11:09:41 [scrapy.middleware] INFO: Enabled spider middlewares:
# ['scrapy.spidermiddlewares.httperror.HttpErrorMiddleware',
#  'scrapy.spidermiddlewares.offsite.OffsiteMiddleware',
#  'scrapy.spidermiddlewares.referer.RefererMiddleware',
#  'scrapy.spidermiddlewares.urllength.UrlLengthMiddleware',
#  'scrapy.spidermiddlewares.depth.DepthMiddleware']
# 2023-11-14 11:09:41 [scrapy.middleware] INFO: Enabled item pipelines:
# []
# 2023-11-14 11:09:41 [scrapy.core.engine] INFO: Spider opened
# 2023-11-14 11:09:42 [scrapy.extensions.logstats] INFO: Crawled 0 pages (at 0 pages/min), scraped 0 items (at 0 items/min)
# 2023-11-14 11:09:42 [scrapy.extensions.telnet] INFO: Telnet console listening on 127.0.0.1:6023
# 2023-11-14 11:09:42 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://books.toscrape.com/catalogue/category/books/travel_2/index.html> (referer: None)
# 2023-11-14 11:09:42 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://books.toscrape.com/catalogue/category/books/sequential-art_5/index.html> (referer: None)
# 2023-11-14 11:09:42 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://books.toscrape.com/catalogue/category/books/mystery_3/index.html> (referer: None)
# 2023-11-14 11:09:42 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://books.toscrape.com/catalogue/category/books/philosophy_7/index.html> (referer: None)
# 2023-11-14 11:09:42 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://books.toscrape.com/catalogue/category/books/romance_8/index.html> (referer: None)
# 2023-11-14 11:09:42 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://books.toscrape.com/catalogue/category/books/womens-fiction_9/index.html> (referer: None)
# 2023-11-14 11:09:42 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://books.toscrape.com/catalogue/category/books/historical-fiction_4/index.html> (referer: None)
# 2023-11-14 11:09:42 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://books.toscrape.com/catalogue/category/books/classics_6/index.html> (referer: None)
# 2023-11-14 11:09:42 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://books.toscrape.com/catalogue/category/books/fiction_10/index.html> (referer: None)
# 2023-11-14 11:09:42 [scrapy.core.engine] INFO: Closing spider (finished)
# 2023-11-14 11:09:42 [scrapy.statscollectors] INFO: Dumping Scrapy stats:
# {'downloader/request_bytes': 2486,
#  'downloader/request_count': 9,
#  'downloader/request_method_count/GET': 9,
#  'downloader/response_bytes': 45370,
#  'downloader/response_count': 9,
#  'downloader/response_status_count/200': 9,
#  'elapsed_time_seconds': 0.257926,
#  'finish_reason': 'finished',
#  'finish_time': datetime.datetime(2023, 11, 14, 16, 9, 42, 656715),
#  'httpcompression/response_bytes': 419249,
#  'httpcompression/response_count': 9,
#  'log_count/DEBUG': 10,
#  'log_count/INFO': 10,
#  'log_count/WARNING': 1,
#  'memusage/max': 246341632,
#  'memusage/startup': 246341632,
#  'response_received_count': 9,
#  'scheduler/dequeued': 9,
#  'scheduler/dequeued/memory': 9,
#  'scheduler/enqueued': 9,
#  'scheduler/enqueued/memory': 9,
#  'start_time': datetime.datetime(2023, 11, 14, 16, 9, 42, 398789)}
# 2023-11-14 11:09:42 [scrapy.core.engine] INFO: Spider closed (finished)
#                                   Book Rating
# 0              It's Only the Himalayas    Two
# 1            Full Moon over Noah’s ...   Four
# 2       See America: A Celebration ...  Three
# 3   Vagabonding: An Uncommon Guide ...    Two
# 4                 Under the Tuscan Sun  Three
# 5                   A Summer In Europe    Two
# 6             The Great Railway Bazaar    One
# 7               A Year in Provence ...   Four
# 8               The Road to Little ...    One
# 9          Neither Here nor There: ...  Three
# 10             1,000 Places to See ...   Five
#                                       Book Rating
# 0      Scott Pilgrim's Precious Little ...   Five
# 1           Tsubasa: WoRLD CHRoNiCLE 2 ...    One
# 2                          This One Summer   Four
# 3               The Nameless City (The ...   Four
# 4                 Saga, Volume 5 (Saga ...    Two
# 5                  Rat Queens, Vol. 3: ...  Three
# 6   Princess Jellyfish 2-in-1 Omnibus, ...   Five
# 7                  Pop Gun War, Volume ...    One
# 8                                 Patience  Three
# 9                   Outcast, Vol. 1: A ...   Four
# 10     orange: The Complete Collection ...    One
# 11     Lumberjanes, Vol. 2: Friendship ...    Two
# 12         Lumberjanes, Vol. 1: Beware ...  Three
# 13               Lumberjanes Vol. 3: A ...    Two
# 14              I Hate Fairyland, Vol. ...    Two
# 15                         I am a Hero ...  Three
# 16                  Giant Days, Vol. 2 ...    Two
# 17                    Danganronpa Volume 1   Four
# 18       Codename Baboushka, Volume 1: ...   Four
# 19                           Camp Midnight   Four
#                                 Book Rating
# 0                      Sharp Objects   Four
# 1                In a Dark, Dark ...    One
# 2                The Past Never Ends   Four
# 3                   A Murder in Time    One
# 4            The Murder of Roger ...   Four
# 5            The Last Mile (Amos ...    Two
# 6    That Darkness (Gardiner and ...    One
# 7           Tastes Like Fear (DI ...    One
# 8              A Time of Torment ...   Five
# 9             A Study in Scarlet ...    Two
# 10  Poisonous (Max Revere Novels ...  Three
# 11            Murder at the 42nd ...   Four
# 12                       Most Wanted  Three
# 13         Hide Away (Eve Duncan ...    One
# 14      Boar Island (Anna Pigeon ...  Three
# 15                         The Widow    Two
# 16                 Playing with Fire  Three
# 17        What Happened on Beale ...   Five
# 18     The Bachelor Girl's Guide ...   Five
# 19  Delivering the Truth (Quaker ...   Four
#                                        Book Rating
# 0                            Sophie's World   Five
# 1                The Death of Humanity: ...   Four
# 2                              The Stranger   Four
# 3              Proofs of God: Classical ...    One
# 4   Kierkegaard: A Christian Missionary ...    One
# 5           At The Existentialist Café: ...   Five
# 6                   Critique of Pure Reason    One
# 7                   Run, Spot, Run: The ...    One
# 8                    The Nicomachean Ethics    One
# 9                               Meditations    Two
# 10                     Beyond Good and Evil    One
#                                    Book Rating
# 0            Chase Me (Paris Nights ...   Five
# 1                            Black Dust   Five
# 2         Her Backup Boyfriend (The ...    One
# 3             First and First (Five ...   Four
# 4        Fifty Shades Darker (Fifty ...    One
# 5                     The Wedding Dress    One
# 6            Suddenly in Love (Lake ...    Two
# 7              Something More Than This   Four
# 8               Doing It Over (Most ...  Three
# 9             The Wedding Pact (The ...  Three
# 10         Hold Your Breath (Search ...    One
# 11                  Dirty (Dive Bar #1)   Four
# 12             Take Me Home Tonight ...  Three
# 13            Off the Hook (Fishing ...  Three
# 14  A Gentleman's Position (Society ...   Five
# 15                      Sit, Stay, Love  Three
# 16                A Girl's Guide to ...    One
# 17           The Perfect Play (Play ...  Three
# 18         Dark Lover (Black Dagger ...    One
# 19          Changing the Game (Play ...  Three
#                                   Book Rating
# 0                     I Had a Nice ...   Four
# 1               Will You Won't You ...  Three
# 2                       Keep Me Posted   Four
# 3               Grey (Fifty Shades #4)   Four
# 4                            Meternity  Three
# 5                           Some Women   Five
# 6         Shopaholic Ties the Knot ...   Five
# 7                   Can You Keep a ...    One
# 8                        Twenties Girl    Two
# 9               The Undomestic Goddess   Four
# 10        The Nanny Diaries (Nanny ...   Five
# 11           The Devil Wears Prada ...    One
# 12     Something Borrowed (Darcy & ...   Five
# 13         Something Blue (Darcy & ...    One
# 14                I've Got Your Number    One
# 15              The Edge of Reason ...   Four
# 16  Bridget Jones's Diary (Bridget ...    One
#                                  Book Rating
# 0                  Tipping the Velvet    One
# 1        Forever and Forever: The ...  Three
# 2              A Flight of Arrows ...   Five
# 3                The House by the ...    One
# 4                        Mrs. Houdini   Five
# 5           The Marriage of Opposites   Four
# 6   Glory over Everything: Beyond ...  Three
# 7                Love, Lies and Spies    Two
# 8                   A Paris Apartment   Four
# 9                         Lilac Girls    Two
# 10     The Constant Princess (The ...  Three
# 11             The Invention of Wings    One
# 12         World Without End (The ...   Four
# 13              The Passion of Dolssa   Five
# 14              Girl With a Pearl ...    One
# 15             Voyager (Outlander #3)   Five
# 16                       The Red Tent   Five
# 17           The Last Painting of ...    Two
# 18      The Guernsey Literary and ...    One
# 19               Girl in the Blue ...    Two
#                                 Book Rating
# 0                  The Secret Garden   Four
# 1                  The Metamorphosis    One
# 2             The Pilgrim's Progress    Two
# 3               The Hound of the ...    Two
# 4     Little Women (Little Women ...   Four
# 5                 Gone with the Wind  Three
# 6                            Candide  Three
# 7                        Animal Farm  Three
# 8                  Wuthering Heights  Three
# 9          The Picture of Dorian ...    Two
# 10      The Complete Stories and ...   Four
# 11                           Beowulf    Two
# 12           And Then There Were ...    Two
# 13             The Story of Hong ...   Four
# 14                 The Little Prince    Two
# 15             Sense and Sensibility    One
# 16                   Of Mice and Men    Two
# 17                              Emma    Two
# 18  Alice in Wonderland (Alice's ...    One
#                                 Book Rating
# 0                         Soumission    One
# 1        Private Paris (Private #10)   Five
# 2           We Love You, Charlie ...   Five
# 3                             Thirst   Five
# 4          The Murder That Never ...  Three
# 5             Tuesday Nights in 1980    Two
# 6                    The Vacationers   Four
# 7         The Regional Office Is ...   Five
# 8   Finders Keepers (Bill Hodges ...   Five
# 9                    The Time Keeper   Five
# 10             The Testament of Mary   Four
# 11       The First Hostage (J.B. ...  Three
# 12                  Take Me with You  Three
# 13         Still Life with Bread ...  Three
# 14                             Shtum   Four
# 15               My Name Is Lucy ...    One
# 16                     My Mrs. Brown  Three
# 17     Mr. Mercedes (Bill Hodges ...    One
# 18         I Am Pilgrim (Pilgrim ...   Four
# 19  Eligible (The Austen Project ...  Three

# %%
"""
# xpath
import scrapy
import pandas as pd
from scrapy.crawler import CrawlerProcess


class BookRatings(scrapy.Spider):
    name = "BookRatings"
    allowed_domains = ['books.toscrape.com']
    start_urls = ['http://books.toscrape.com/catalogue/category/books/travel_2/index.html',
                  'http://books.toscrape.com/catalogue/category/books/mystery_3/index.html',
                  'http://books.toscrape.com/catalogue/category/books/historical-fiction_4/index.html',
                  'http://books.toscrape.com/catalogue/category/books/sequential-art_5/index.html',
                  'http://books.toscrape.com/catalogue/category/books/classics_6/index.html',
                  'http://books.toscrape.com/catalogue/category/books/philosophy_7/index.html',
                  'http://books.toscrape.com/catalogue/category/books/romance_8/index.html',
                  'http://books.toscrape.com/catalogue/category/books/womens-fiction_9/index.html',
                  'http://books.toscrape.com/catalogue/category/books/fiction_10/index.html']
    
    def parse(self, response):
        print("Processing:" + response.url)
        
        url = response.url
        
        items = response.xpath("//ol/li/*")
        books = []
        
        for item in items:
            
            name   = str(item.xpath('//h3/a/text()').extract()).strip("]").strip("[").strip("'").strip("\"")
            price  = item.xpath('//div[@class="product_price"]/p/text()')[0].extract()
            rating = item.xpath('//p[contains(@class, "star-rating')[0].extract()
            link   = str(item.xpath('//h3/a/@href').extract()).strip("]").strip("[").strip("'").strip("\"").replace("../../../", "http://books.toscrape.com/catalogue/")

            books.append([url[6], name, price, rating, link])
        
        df = pd.DataFrame(books, columns = ['url', 'book name', 'price', 'rating', 'link'])
        
        number_mapping = {'star-rating One':1,'star-rating Two':2,'star-rating Three':3,'star-rating Four':4,'star-rating Five':5}
        df["Star Rating"] = df["Star Rating"].apply(lambda x : number_mapping.get(x))
        
        df.to_csv("book-ratings-" + url[6] + ".csv", sep=',', encoding='utf-8', mode='w', index=False)
        
        yield df


process = CrawlerProcess()
process.crawl(BookRatings)
process.start()
"""
# Out:
# 2023-11-14 11:25:45 [scrapy.utils.log] INFO: Scrapy 2.8.0 started (bot: scrapybot)
# 2023-11-14 11:25:45 [scrapy.utils.log] INFO: Versions: lxml 4.9.1.0, libxml2 2.9.14, cssselect 1.1.0, parsel 1.6.0, w3lib 1.21.0, Twisted 22.10.0, Python 3.11.3 (main, Apr 19 2023, 23:54:32) [GCC 11.2.0], pyOpenSSL 23.0.0 (OpenSSL 1.1.1w  11 Sep 2023), cryptography 39.0.1, Platform Linux-5.15.0-86-generic-x86_64-with-glibc2.31
# 2023-11-14 11:25:45 [scrapy.crawler] INFO: Overridden settings:
# {}
# 2023-11-14 11:25:45 [py.warnings] WARNING: /mnt/home/kxs997/anaconda3/lib/python3.11/site-packages/scrapy/utils/request.py:232: ScrapyDeprecationWarning: '2.6' is a deprecated value for the 'REQUEST_FINGERPRINTER_IMPLEMENTATION' setting.
#
# It is also the default value. In other words, it is normal to get this warning if you have not defined a value for the 'REQUEST_FINGERPRINTER_IMPLEMENTATION' setting. This is so for backward compatibility reasons, but it will change in a future version of Scrapy.
#
# See the documentation of the 'REQUEST_FINGERPRINTER_IMPLEMENTATION' setting for information on how to handle this deprecation.
#   return cls(crawler)
#
# 2023-11-14 11:25:45 [scrapy.utils.log] DEBUG: Using reactor: twisted.internet.epollreactor.EPollReactor
# 2023-11-14 11:25:45 [scrapy.extensions.telnet] INFO: Telnet Password: ac4fa18c068c1515
# 2023-11-14 11:25:45 [scrapy.middleware] INFO: Enabled extensions:
# ['scrapy.extensions.corestats.CoreStats',
#  'scrapy.extensions.telnet.TelnetConsole',
#  'scrapy.extensions.memusage.MemoryUsage',
#  'scrapy.extensions.logstats.LogStats']
# 2023-11-14 11:25:45 [scrapy.middleware] INFO: Enabled downloader middlewares:
# ['scrapy.downloadermiddlewares.httpauth.HttpAuthMiddleware',
#  'scrapy.downloadermiddlewares.downloadtimeout.DownloadTimeoutMiddleware',
#  'scrapy.downloadermiddlewares.defaultheaders.DefaultHeadersMiddleware',
#  'scrapy.downloadermiddlewares.useragent.UserAgentMiddleware',
#  'scrapy.downloadermiddlewares.retry.RetryMiddleware',
#  'scrapy.downloadermiddlewares.redirect.MetaRefreshMiddleware',
#  'scrapy.downloadermiddlewares.httpcompression.HttpCompressionMiddleware',
#  'scrapy.downloadermiddlewares.redirect.RedirectMiddleware',
#  'scrapy.downloadermiddlewares.cookies.CookiesMiddleware',
#  'scrapy.downloadermiddlewares.httpproxy.HttpProxyMiddleware',
#  'scrapy.downloadermiddlewares.stats.DownloaderStats']
# 2023-11-14 11:25:45 [scrapy.middleware] INFO: Enabled spider middlewares:
# ['scrapy.spidermiddlewares.httperror.HttpErrorMiddleware',
#  'scrapy.spidermiddlewares.offsite.OffsiteMiddleware',
#  'scrapy.spidermiddlewares.referer.RefererMiddleware',
#  'scrapy.spidermiddlewares.urllength.UrlLengthMiddleware',
#  'scrapy.spidermiddlewares.depth.DepthMiddleware']
# 2023-11-14 11:25:45 [scrapy.middleware] INFO: Enabled item pipelines:
# []
# 2023-11-14 11:25:45 [scrapy.core.engine] INFO: Spider opened
# 2023-11-14 11:25:45 [scrapy.extensions.logstats] INFO: Crawled 0 pages (at 0 pages/min), scraped 0 items (at 0 items/min)
# 2023-11-14 11:25:45 [scrapy.extensions.telnet] INFO: Telnet console listening on 127.0.0.1:6023
# 2023-11-14 11:25:45 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://books.toscrape.com/catalogue/category/books/travel_2/index.html> (referer: None)
# 2023-11-14 11:25:45 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://books.toscrape.com/catalogue/category/books/mystery_3/index.html> (referer: None)
# 2023-11-14 11:25:45 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://books.toscrape.com/catalogue/category/books/womens-fiction_9/index.html> (referer: None)
# 2023-11-14 11:25:45 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://books.toscrape.com/catalogue/category/books/historical-fiction_4/index.html> (referer: None)
# 2023-11-14 11:25:45 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://books.toscrape.com/catalogue/category/books/romance_8/index.html> (referer: None)
# 2023-11-14 11:25:45 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://books.toscrape.com/catalogue/category/books/philosophy_7/index.html> (referer: None)
# 2023-11-14 11:25:45 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://books.toscrape.com/catalogue/category/books/sequential-art_5/index.html> (referer: None)
# 2023-11-14 11:25:45 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://books.toscrape.com/catalogue/category/books/fiction_10/index.html> (referer: None)
# 2023-11-14 11:25:45 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://books.toscrape.com/catalogue/category/books/classics_6/index.html> (referer: None)
# 2023-11-14 11:25:45 [scrapy.core.scraper] ERROR: Spider error processing <GET http://books.toscrape.com/catalogue/category/books/travel_2/index.html> (referer: None)
# Traceback (most recent call last):
#   File "/mnt/home/kxs997/anaconda3/lib/python3.11/site-packages/parsel/selector.py", line 254, in xpath
#     result = xpathev(query, namespaces=nsp,
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "src/lxml/etree.pyx", line 1599, in lxml.etree._Element.xpath
#   File "src/lxml/xpath.pxi", line 305, in lxml.etree.XPathElementEvaluator.__call__
#   File "src/lxml/xpath.pxi", line 225, in lxml.etree._XPathEvaluatorBase._handle_result
# lxml.etree.XPathEvalError: Unfinished literal
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/mnt/home/kxs997/anaconda3/lib/python3.11/site-packages/scrapy/utils/defer.py", line 257, in iter_errback
#     yield next(it)
#           ^^^^^^^^
#   File "/mnt/home/kxs997/anaconda3/lib/python3.11/site-packages/scrapy/utils/python.py", line 312, in __next__
#     return next(self.data)
#            ^^^^^^^^^^^^^^^
#   File "/mnt/home/kxs997/anaconda3/lib/python3.11/site-packages/scrapy/utils/python.py", line 312, in __next__
#     return next(self.data)
#            ^^^^^^^^^^^^^^^
#   File "/mnt/home/kxs997/anaconda3/lib/python3.11/site-packages/scrapy/core/spidermw.py", line 104, in process_sync
#     for r in iterable:
#   File "/mnt/home/kxs997/anaconda3/lib/python3.11/site-packages/scrapy/spidermiddlewares/offsite.py", line 28, in <genexpr>
#     return (r for r in result or () if self._filter(r, spider))
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/mnt/home/kxs997/anaconda3/lib/python3.11/site-packages/scrapy/core/spidermw.py", line 104, in process_sync
#     for r in iterable:
#   File "/mnt/home/kxs997/anaconda3/lib/python3.11/site-packages/scrapy/spidermiddlewares/referer.py", line 353, in <genexpr>
#     return (self._set_referer(r, response) for r in result or ())
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/mnt/home/kxs997/anaconda3/lib/python3.11/site-packages/scrapy/core/spidermw.py", line 104, in process_sync
#     for r in iterable:
#   File "/mnt/home/kxs997/anaconda3/lib/python3.11/site-packages/scrapy/spidermiddlewares/urllength.py", line 27, in <genexpr>
#     return (r for r in result or () if self._filter(r, spider))
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/mnt/home/kxs997/anaconda3/lib/python3.11/site-packages/scrapy/core/spidermw.py", line 104, in process_sync
#     for r in iterable:
#   File "/mnt/home/kxs997/anaconda3/lib/python3.11/site-packages/scrapy/spidermiddlewares/depth.py", line 31, in <genexpr>
#     return (r for r in result or () if self._filter(r, response, spider))
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/mnt/home/kxs997/anaconda3/lib/python3.11/site-packages/scrapy/core/spidermw.py", line 104, in process_sync
#     for r in iterable:
#   File "/tmp/ipykernel_18287/315165690.py", line 32, in parse
#     rating = item.xpath('//p[contains(@class, "star-rating')[0].extract()
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/mnt/home/kxs997/anaconda3/lib/python3.11/site-packages/parsel/selector.py", line 260, in xpath
#     six.reraise(ValueError, ValueError(msg), sys.exc_info()[2])
#   File "/mnt/home/kxs997/anaconda3/lib/python3.11/site-packages/six.py", line 718, in reraise
#     raise value.with_traceback(tb)
#   File "/mnt/home/kxs997/anaconda3/lib/python3.11/site-packages/parsel/selector.py", line 254, in xpath
#     result = xpathev(query, namespaces=nsp,
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "src/lxml/etree.pyx", line 1599, in lxml.etree._Element.xpath
#   File "src/lxml/xpath.pxi", line 305, in lxml.etree.XPathElementEvaluator.__call__
#   File "src/lxml/xpath.pxi", line 225, in lxml.etree._XPathEvaluatorBase._handle_result
# ValueError: XPath error: Unfinished literal in //p[contains(@class, "star-rating
# 2023-11-14 11:25:45 [scrapy.core.scraper] ERROR: Spider error processing <GET http://books.toscrape.com/catalogue/category/books/mystery_3/index.html> (referer: None)
# Traceback (most recent call last):
#   File "/mnt/home/kxs997/anaconda3/lib/python3.11/site-packages/parsel/selector.py", line 254, in xpath
#     result = xpathev(query, namespaces=nsp,
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "src/lxml/etree.pyx", line 1599, in lxml.etree._Element.xpath
#   File "src/lxml/xpath.pxi", line 305, in lxml.etree.XPathElementEvaluator.__call__
#   File "src/lxml/xpath.pxi", line 225, in lxml.etree._XPathEvaluatorBase._handle_result
# lxml.etree.XPathEvalError: Unfinished literal
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/mnt/home/kxs997/anaconda3/lib/python3.11/site-packages/scrapy/utils/defer.py", line 257, in iter_errback
#     yield next(it)
#           ^^^^^^^^
#   File "/mnt/home/kxs997/anaconda3/lib/python3.11/site-packages/scrapy/utils/python.py", line 312, in __next__
#     return next(self.data)
#            ^^^^^^^^^^^^^^^
#   File "/mnt/home/kxs997/anaconda3/lib/python3.11/site-packages/scrapy/utils/python.py", line 312, in __next__
#     return next(self.data)
#            ^^^^^^^^^^^^^^^
#   File "/mnt/home/kxs997/anaconda3/lib/python3.11/site-packages/scrapy/core/spidermw.py", line 104, in process_sync
#     for r in iterable:
#   File "/mnt/home/kxs997/anaconda3/lib/python3.11/site-packages/scrapy/spidermiddlewares/offsite.py", line 28, in <genexpr>
#     return (r for r in result or () if self._filter(r, spider))
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/mnt/home/kxs997/anaconda3/lib/python3.11/site-packages/scrapy/core/spidermw.py", line 104, in process_sync
#     for r in iterable:
#   File "/mnt/home/kxs997/anaconda3/lib/python3.11/site-packages/scrapy/spidermiddlewares/referer.py", line 353, in <genexpr>
#     return (self._set_referer(r, response) for r in result or ())
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/mnt/home/kxs997/anaconda3/lib/python3.11/site-packages/scrapy/core/spidermw.py", line 104, in process_sync
#     for r in iterable:
#   File "/mnt/home/kxs997/anaconda3/lib/python3.11/site-packages/scrapy/spidermiddlewares/urllength.py", line 27, in <genexpr>
#     return (r for r in result or () if self._filter(r, spider))
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/mnt/home/kxs997/anaconda3/lib/python3.11/site-packages/scrapy/core/spidermw.py", line 104, in process_sync
#     for r in iterable:
#   File "/mnt/home/kxs997/anaconda3/lib/python3.11/site-packages/scrapy/spidermiddlewares/depth.py", line 31, in <genexpr>
#     return (r for r in result or () if self._filter(r, response, spider))
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/mnt/home/kxs997/anaconda3/lib/python3.11/site-packages/scrapy/core/spidermw.py", line 104, in process_sync
#     for r in iterable:
#   File "/tmp/ipykernel_18287/315165690.py", line 32, in parse
#     rating = item.xpath('//p[contains(@class, "star-rating')[0].extract()
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/mnt/home/kxs997/anaconda3/lib/python3.11/site-packages/parsel/selector.py", line 260, in xpath
#     six.reraise(ValueError, ValueError(msg), sys.exc_info()[2])
#   File "/mnt/home/kxs997/anaconda3/lib/python3.11/site-packages/six.py", line 718, in reraise
#     raise value.with_traceback(tb)
#   File "/mnt/home/kxs997/anaconda3/lib/python3.11/site-packages/parsel/selector.py", line 254, in xpath
#     result = xpathev(query, namespaces=nsp,
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "src/lxml/etree.pyx", line 1599, in lxml.etree._Element.xpath
#   File "src/lxml/xpath.pxi", line 305, in lxml.etree.XPathElementEvaluator.__call__
#   File "src/lxml/xpath.pxi", line 225, in lxml.etree._XPathEvaluatorBase._handle_result
# ValueError: XPath error: Unfinished literal in //p[contains(@class, "star-rating
# 2023-11-14 11:25:46 [scrapy.core.scraper] ERROR: Spider error processing <GET http://books.toscrape.com/catalogue/category/books/womens-fiction_9/index.html> (referer: None)
# Traceback (most recent call last):
#   File "/mnt/home/kxs997/anaconda3/lib/python3.11/site-packages/parsel/selector.py", line 254, in xpath
#     result = xpathev(query, namespaces=nsp,
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "src/lxml/etree.pyx", line 1599, in lxml.etree._Element.xpath
#   File "src/lxml/xpath.pxi", line 305, in lxml.etree.XPathElementEvaluator.__call__
#   File "src/lxml/xpath.pxi", line 225, in lxml.etree._XPathEvaluatorBase._handle_result
# lxml.etree.XPathEvalError: Unfinished literal
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/mnt/home/kxs997/anaconda3/lib/python3.11/site-packages/scrapy/utils/defer.py", line 257, in iter_errback
#     yield next(it)
#           ^^^^^^^^
#   File "/mnt/home/kxs997/anaconda3/lib/python3.11/site-packages/scrapy/utils/python.py", line 312, in __next__
#     return next(self.data)
#            ^^^^^^^^^^^^^^^
#   File "/mnt/home/kxs997/anaconda3/lib/python3.11/site-packages/scrapy/utils/python.py", line 312, in __next__
#     return next(self.data)
#            ^^^^^^^^^^^^^^^
#   File "/mnt/home/kxs997/anaconda3/lib/python3.11/site-packages/scrapy/core/spidermw.py", line 104, in process_sync
#     for r in iterable:
#   File "/mnt/home/kxs997/anaconda3/lib/python3.11/site-packages/scrapy/spidermiddlewares/offsite.py", line 28, in <genexpr>
#     return (r for r in result or () if self._filter(r, spider))
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/mnt/home/kxs997/anaconda3/lib/python3.11/site-packages/scrapy/core/spidermw.py", line 104, in process_sync
#     for r in iterable:
#   File "/mnt/home/kxs997/anaconda3/lib/python3.11/site-packages/scrapy/spidermiddlewares/referer.py", line 353, in <genexpr>
#     return (self._set_referer(r, response) for r in result or ())
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/mnt/home/kxs997/anaconda3/lib/python3.11/site-packages/scrapy/core/spidermw.py", line 104, in process_sync
#     for r in iterable:
#   File "/mnt/home/kxs997/anaconda3/lib/python3.11/site-packages/scrapy/spidermiddlewares/urllength.py", line 27, in <genexpr>
#     return (r for r in result or () if self._filter(r, spider))
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/mnt/home/kxs997/anaconda3/lib/python3.11/site-packages/scrapy/core/spidermw.py", line 104, in process_sync
#     for r in iterable:
#   File "/mnt/home/kxs997/anaconda3/lib/python3.11/site-packages/scrapy/spidermiddlewares/depth.py", line 31, in <genexpr>
#     return (r for r in result or () if self._filter(r, response, spider))
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/mnt/home/kxs997/anaconda3/lib/python3.11/site-packages/scrapy/core/spidermw.py", line 104, in process_sync
#     for r in iterable:
#   File "/tmp/ipykernel_18287/315165690.py", line 32, in parse
#     rating = item.xpath('//p[contains(@class, "star-rating')[0].extract()
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/mnt/home/kxs997/anaconda3/lib/python3.11/site-packages/parsel/selector.py", line 260, in xpath
#     six.reraise(ValueError, ValueError(msg), sys.exc_info()[2])
#   File "/mnt/home/kxs997/anaconda3/lib/python3.11/site-packages/six.py", line 718, in reraise
#     raise value.with_traceback(tb)
#   File "/mnt/home/kxs997/anaconda3/lib/python3.11/site-packages/parsel/selector.py", line 254, in xpath
#     result = xpathev(query, namespaces=nsp,
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "src/lxml/etree.pyx", line 1599, in lxml.etree._Element.xpath
#   File "src/lxml/xpath.pxi", line 305, in lxml.etree.XPathElementEvaluator.__call__
#   File "src/lxml/xpath.pxi", line 225, in lxml.etree._XPathEvaluatorBase._handle_result
# ValueError: XPath error: Unfinished literal in //p[contains(@class, "star-rating
# 2023-11-14 11:25:46 [scrapy.core.scraper] ERROR: Spider error processing <GET http://books.toscrape.com/catalogue/category/books/historical-fiction_4/index.html> (referer: None)
# Traceback (most recent call last):
#   File "/mnt/home/kxs997/anaconda3/lib/python3.11/site-packages/parsel/selector.py", line 254, in xpath
#     result = xpathev(query, namespaces=nsp,
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "src/lxml/etree.pyx", line 1599, in lxml.etree._Element.xpath
#   File "src/lxml/xpath.pxi", line 305, in lxml.etree.XPathElementEvaluator.__call__
#   File "src/lxml/xpath.pxi", line 225, in lxml.etree._XPathEvaluatorBase._handle_result
# lxml.etree.XPathEvalError: Unfinished literal
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/mnt/home/kxs997/anaconda3/lib/python3.11/site-packages/scrapy/utils/defer.py", line 257, in iter_errback
#     yield next(it)
#           ^^^^^^^^
#   File "/mnt/home/kxs997/anaconda3/lib/python3.11/site-packages/scrapy/utils/python.py", line 312, in __next__
#     return next(self.data)
#            ^^^^^^^^^^^^^^^
#   File "/mnt/home/kxs997/anaconda3/lib/python3.11/site-packages/scrapy/utils/python.py", line 312, in __next__
#     return next(self.data)
#            ^^^^^^^^^^^^^^^
#   File "/mnt/home/kxs997/anaconda3/lib/python3.11/site-packages/scrapy/core/spidermw.py", line 104, in process_sync
#     for r in iterable:
#   File "/mnt/home/kxs997/anaconda3/lib/python3.11/site-packages/scrapy/spidermiddlewares/offsite.py", line 28, in <genexpr>
#     return (r for r in result or () if self._filter(r, spider))
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/mnt/home/kxs997/anaconda3/lib/python3.11/site-packages/scrapy/core/spidermw.py", line 104, in process_sync
#     for r in iterable:
#   File "/mnt/home/kxs997/anaconda3/lib/python3.11/site-packages/scrapy/spidermiddlewares/referer.py", line 353, in <genexpr>
#     return (self._set_referer(r, response) for r in result or ())
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/mnt/home/kxs997/anaconda3/lib/python3.11/site-packages/scrapy/core/spidermw.py", line 104, in process_sync
#     for r in iterable:
#   File "/mnt/home/kxs997/anaconda3/lib/python3.11/site-packages/scrapy/spidermiddlewares/urllength.py", line 27, in <genexpr>
#     return (r for r in result or () if self._filter(r, spider))
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/mnt/home/kxs997/anaconda3/lib/python3.11/site-packages/scrapy/core/spidermw.py", line 104, in process_sync
#     for r in iterable:
#   File "/mnt/home/kxs997/anaconda3/lib/python3.11/site-packages/scrapy/spidermiddlewares/depth.py", line 31, in <genexpr>
#     return (r for r in result or () if self._filter(r, response, spider))
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/mnt/home/kxs997/anaconda3/lib/python3.11/site-packages/scrapy/core/spidermw.py", line 104, in process_sync
#     for r in iterable:
#   File "/tmp/ipykernel_18287/315165690.py", line 32, in parse
#     rating = item.xpath('//p[contains(@class, "star-rating')[0].extract()
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/mnt/home/kxs997/anaconda3/lib/python3.11/site-packages/parsel/selector.py", line 260, in xpath
#     six.reraise(ValueError, ValueError(msg), sys.exc_info()[2])
#   File "/mnt/home/kxs997/anaconda3/lib/python3.11/site-packages/six.py", line 718, in reraise
#     raise value.with_traceback(tb)
#   File "/mnt/home/kxs997/anaconda3/lib/python3.11/site-packages/parsel/selector.py", line 254, in xpath
#     result = xpathev(query, namespaces=nsp,
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "src/lxml/etree.pyx", line 1599, in lxml.etree._Element.xpath
#   File "src/lxml/xpath.pxi", line 305, in lxml.etree.XPathElementEvaluator.__call__
#   File "src/lxml/xpath.pxi", line 225, in lxml.etree._XPathEvaluatorBase._handle_result
# ValueError: XPath error: Unfinished literal in //p[contains(@class, "star-rating
# 2023-11-14 11:25:46 [scrapy.core.scraper] ERROR: Spider error processing <GET http://books.toscrape.com/catalogue/category/books/romance_8/index.html> (referer: None)
# Traceback (most recent call last):
#   File "/mnt/home/kxs997/anaconda3/lib/python3.11/site-packages/parsel/selector.py", line 254, in xpath
#     result = xpathev(query, namespaces=nsp,
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "src/lxml/etree.pyx", line 1599, in lxml.etree._Element.xpath
#   File "src/lxml/xpath.pxi", line 305, in lxml.etree.XPathElementEvaluator.__call__
#   File "src/lxml/xpath.pxi", line 225, in lxml.etree._XPathEvaluatorBase._handle_result
# lxml.etree.XPathEvalError: Unfinished literal
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/mnt/home/kxs997/anaconda3/lib/python3.11/site-packages/scrapy/utils/defer.py", line 257, in iter_errback
#     yield next(it)
#           ^^^^^^^^
#   File "/mnt/home/kxs997/anaconda3/lib/python3.11/site-packages/scrapy/utils/python.py", line 312, in __next__
#     return next(self.data)
#            ^^^^^^^^^^^^^^^
#   File "/mnt/home/kxs997/anaconda3/lib/python3.11/site-packages/scrapy/utils/python.py", line 312, in __next__
#     return next(self.data)
#            ^^^^^^^^^^^^^^^
#   File "/mnt/home/kxs997/anaconda3/lib/python3.11/site-packages/scrapy/core/spidermw.py", line 104, in process_sync
#     for r in iterable:
#   File "/mnt/home/kxs997/anaconda3/lib/python3.11/site-packages/scrapy/spidermiddlewares/offsite.py", line 28, in <genexpr>
#     return (r for r in result or () if self._filter(r, spider))
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/mnt/home/kxs997/anaconda3/lib/python3.11/site-packages/scrapy/core/spidermw.py", line 104, in process_sync
#     for r in iterable:
#   File "/mnt/home/kxs997/anaconda3/lib/python3.11/site-packages/scrapy/spidermiddlewares/referer.py", line 353, in <genexpr>
#     return (self._set_referer(r, response) for r in result or ())
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/mnt/home/kxs997/anaconda3/lib/python3.11/site-packages/scrapy/core/spidermw.py", line 104, in process_sync
#     for r in iterable:
#   File "/mnt/home/kxs997/anaconda3/lib/python3.11/site-packages/scrapy/spidermiddlewares/urllength.py", line 27, in <genexpr>
#     return (r for r in result or () if self._filter(r, spider))
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/mnt/home/kxs997/anaconda3/lib/python3.11/site-packages/scrapy/core/spidermw.py", line 104, in process_sync
#     for r in iterable:
#   File "/mnt/home/kxs997/anaconda3/lib/python3.11/site-packages/scrapy/spidermiddlewares/depth.py", line 31, in <genexpr>
#     return (r for r in result or () if self._filter(r, response, spider))
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/mnt/home/kxs997/anaconda3/lib/python3.11/site-packages/scrapy/core/spidermw.py", line 104, in process_sync
#     for r in iterable:
#   File "/tmp/ipykernel_18287/315165690.py", line 32, in parse
#     rating = item.xpath('//p[contains(@class, "star-rating')[0].extract()
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/mnt/home/kxs997/anaconda3/lib/python3.11/site-packages/parsel/selector.py", line 260, in xpath
#     six.reraise(ValueError, ValueError(msg), sys.exc_info()[2])
#   File "/mnt/home/kxs997/anaconda3/lib/python3.11/site-packages/six.py", line 718, in reraise
#     raise value.with_traceback(tb)
#   File "/mnt/home/kxs997/anaconda3/lib/python3.11/site-packages/parsel/selector.py", line 254, in xpath
#     result = xpathev(query, namespaces=nsp,
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "src/lxml/etree.pyx", line 1599, in lxml.etree._Element.xpath
#   File "src/lxml/xpath.pxi", line 305, in lxml.etree.XPathElementEvaluator.__call__
#   File "src/lxml/xpath.pxi", line 225, in lxml.etree._XPathEvaluatorBase._handle_result
# ValueError: XPath error: Unfinished literal in //p[contains(@class, "star-rating
# 2023-11-14 11:25:46 [scrapy.core.scraper] ERROR: Spider error processing <GET http://books.toscrape.com/catalogue/category/books/philosophy_7/index.html> (referer: None)
# Traceback (most recent call last):
#   File "/mnt/home/kxs997/anaconda3/lib/python3.11/site-packages/parsel/selector.py", line 254, in xpath
#     result = xpathev(query, namespaces=nsp,
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "src/lxml/etree.pyx", line 1599, in lxml.etree._Element.xpath
#   File "src/lxml/xpath.pxi", line 305, in lxml.etree.XPathElementEvaluator.__call__
#   File "src/lxml/xpath.pxi", line 225, in lxml.etree._XPathEvaluatorBase._handle_result
# lxml.etree.XPathEvalError: Unfinished literal
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/mnt/home/kxs997/anaconda3/lib/python3.11/site-packages/scrapy/utils/defer.py", line 257, in iter_errback
#     yield next(it)
#           ^^^^^^^^
#   File "/mnt/home/kxs997/anaconda3/lib/python3.11/site-packages/scrapy/utils/python.py", line 312, in __next__
#     return next(self.data)
#            ^^^^^^^^^^^^^^^
#   File "/mnt/home/kxs997/anaconda3/lib/python3.11/site-packages/scrapy/utils/python.py", line 312, in __next__
#     return next(self.data)
#            ^^^^^^^^^^^^^^^
#   File "/mnt/home/kxs997/anaconda3/lib/python3.11/site-packages/scrapy/core/spidermw.py", line 104, in process_sync
#     for r in iterable:
#   File "/mnt/home/kxs997/anaconda3/lib/python3.11/site-packages/scrapy/spidermiddlewares/offsite.py", line 28, in <genexpr>
#     return (r for r in result or () if self._filter(r, spider))
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/mnt/home/kxs997/anaconda3/lib/python3.11/site-packages/scrapy/core/spidermw.py", line 104, in process_sync
#     for r in iterable:
#   File "/mnt/home/kxs997/anaconda3/lib/python3.11/site-packages/scrapy/spidermiddlewares/referer.py", line 353, in <genexpr>
#     return (self._set_referer(r, response) for r in result or ())
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/mnt/home/kxs997/anaconda3/lib/python3.11/site-packages/scrapy/core/spidermw.py", line 104, in process_sync
#     for r in iterable:
#   File "/mnt/home/kxs997/anaconda3/lib/python3.11/site-packages/scrapy/spidermiddlewares/urllength.py", line 27, in <genexpr>
#     return (r for r in result or () if self._filter(r, spider))
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/mnt/home/kxs997/anaconda3/lib/python3.11/site-packages/scrapy/core/spidermw.py", line 104, in process_sync
#     for r in iterable:
#   File "/mnt/home/kxs997/anaconda3/lib/python3.11/site-packages/scrapy/spidermiddlewares/depth.py", line 31, in <genexpr>
#     return (r for r in result or () if self._filter(r, response, spider))
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/mnt/home/kxs997/anaconda3/lib/python3.11/site-packages/scrapy/core/spidermw.py", line 104, in process_sync
#     for r in iterable:
#   File "/tmp/ipykernel_18287/315165690.py", line 32, in parse
#     rating = item.xpath('//p[contains(@class, "star-rating')[0].extract()
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/mnt/home/kxs997/anaconda3/lib/python3.11/site-packages/parsel/selector.py", line 260, in xpath
#     six.reraise(ValueError, ValueError(msg), sys.exc_info()[2])
#   File "/mnt/home/kxs997/anaconda3/lib/python3.11/site-packages/six.py", line 718, in reraise
#     raise value.with_traceback(tb)
#   File "/mnt/home/kxs997/anaconda3/lib/python3.11/site-packages/parsel/selector.py", line 254, in xpath
#     result = xpathev(query, namespaces=nsp,
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "src/lxml/etree.pyx", line 1599, in lxml.etree._Element.xpath
#   File "src/lxml/xpath.pxi", line 305, in lxml.etree.XPathElementEvaluator.__call__
#   File "src/lxml/xpath.pxi", line 225, in lxml.etree._XPathEvaluatorBase._handle_result
# ValueError: XPath error: Unfinished literal in //p[contains(@class, "star-rating
# 2023-11-14 11:25:46 [scrapy.core.scraper] ERROR: Spider error processing <GET http://books.toscrape.com/catalogue/category/books/sequential-art_5/index.html> (referer: None)
# Traceback (most recent call last):
#   File "/mnt/home/kxs997/anaconda3/lib/python3.11/site-packages/parsel/selector.py", line 254, in xpath
#     result = xpathev(query, namespaces=nsp,
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "src/lxml/etree.pyx", line 1599, in lxml.etree._Element.xpath
#   File "src/lxml/xpath.pxi", line 305, in lxml.etree.XPathElementEvaluator.__call__
#   File "src/lxml/xpath.pxi", line 225, in lxml.etree._XPathEvaluatorBase._handle_result
# lxml.etree.XPathEvalError: Unfinished literal
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/mnt/home/kxs997/anaconda3/lib/python3.11/site-packages/scrapy/utils/defer.py", line 257, in iter_errback
#     yield next(it)
#           ^^^^^^^^
#   File "/mnt/home/kxs997/anaconda3/lib/python3.11/site-packages/scrapy/utils/python.py", line 312, in __next__
#     return next(self.data)
#            ^^^^^^^^^^^^^^^
#   File "/mnt/home/kxs997/anaconda3/lib/python3.11/site-packages/scrapy/utils/python.py", line 312, in __next__
#     return next(self.data)
#            ^^^^^^^^^^^^^^^
#   File "/mnt/home/kxs997/anaconda3/lib/python3.11/site-packages/scrapy/core/spidermw.py", line 104, in process_sync
#     for r in iterable:
#   File "/mnt/home/kxs997/anaconda3/lib/python3.11/site-packages/scrapy/spidermiddlewares/offsite.py", line 28, in <genexpr>
#     return (r for r in result or () if self._filter(r, spider))
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/mnt/home/kxs997/anaconda3/lib/python3.11/site-packages/scrapy/core/spidermw.py", line 104, in process_sync
#     for r in iterable:
#   File "/mnt/home/kxs997/anaconda3/lib/python3.11/site-packages/scrapy/spidermiddlewares/referer.py", line 353, in <genexpr>
#     return (self._set_referer(r, response) for r in result or ())
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/mnt/home/kxs997/anaconda3/lib/python3.11/site-packages/scrapy/core/spidermw.py", line 104, in process_sync
#     for r in iterable:
#   File "/mnt/home/kxs997/anaconda3/lib/python3.11/site-packages/scrapy/spidermiddlewares/urllength.py", line 27, in <genexpr>
#     return (r for r in result or () if self._filter(r, spider))
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/mnt/home/kxs997/anaconda3/lib/python3.11/site-packages/scrapy/core/spidermw.py", line 104, in process_sync
#     for r in iterable:
#   File "/mnt/home/kxs997/anaconda3/lib/python3.11/site-packages/scrapy/spidermiddlewares/depth.py", line 31, in <genexpr>
#     return (r for r in result or () if self._filter(r, response, spider))
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/mnt/home/kxs997/anaconda3/lib/python3.11/site-packages/scrapy/core/spidermw.py", line 104, in process_sync
#     for r in iterable:
#   File "/tmp/ipykernel_18287/315165690.py", line 32, in parse
#     rating = item.xpath('//p[contains(@class, "star-rating')[0].extract()
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/mnt/home/kxs997/anaconda3/lib/python3.11/site-packages/parsel/selector.py", line 260, in xpath
#     six.reraise(ValueError, ValueError(msg), sys.exc_info()[2])
#   File "/mnt/home/kxs997/anaconda3/lib/python3.11/site-packages/six.py", line 718, in reraise
#     raise value.with_traceback(tb)
#   File "/mnt/home/kxs997/anaconda3/lib/python3.11/site-packages/parsel/selector.py", line 254, in xpath
#     result = xpathev(query, namespaces=nsp,
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "src/lxml/etree.pyx", line 1599, in lxml.etree._Element.xpath
#   File "src/lxml/xpath.pxi", line 305, in lxml.etree.XPathElementEvaluator.__call__
#   File "src/lxml/xpath.pxi", line 225, in lxml.etree._XPathEvaluatorBase._handle_result
# ValueError: XPath error: Unfinished literal in //p[contains(@class, "star-rating
# 2023-11-14 11:25:46 [scrapy.core.scraper] ERROR: Spider error processing <GET http://books.toscrape.com/catalogue/category/books/fiction_10/index.html> (referer: None)
# Traceback (most recent call last):
#   File "/mnt/home/kxs997/anaconda3/lib/python3.11/site-packages/parsel/selector.py", line 254, in xpath
#     result = xpathev(query, namespaces=nsp,
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "src/lxml/etree.pyx", line 1599, in lxml.etree._Element.xpath
#   File "src/lxml/xpath.pxi", line 305, in lxml.etree.XPathElementEvaluator.__call__
#   File "src/lxml/xpath.pxi", line 225, in lxml.etree._XPathEvaluatorBase._handle_result
# lxml.etree.XPathEvalError: Unfinished literal
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/mnt/home/kxs997/anaconda3/lib/python3.11/site-packages/scrapy/utils/defer.py", line 257, in iter_errback
#     yield next(it)
#           ^^^^^^^^
#   File "/mnt/home/kxs997/anaconda3/lib/python3.11/site-packages/scrapy/utils/python.py", line 312, in __next__
#     return next(self.data)
#            ^^^^^^^^^^^^^^^
#   File "/mnt/home/kxs997/anaconda3/lib/python3.11/site-packages/scrapy/utils/python.py", line 312, in __next__
#     return next(self.data)
#            ^^^^^^^^^^^^^^^
#   File "/mnt/home/kxs997/anaconda3/lib/python3.11/site-packages/scrapy/core/spidermw.py", line 104, in process_sync
#     for r in iterable:
#   File "/mnt/home/kxs997/anaconda3/lib/python3.11/site-packages/scrapy/spidermiddlewares/offsite.py", line 28, in <genexpr>
#     return (r for r in result or () if self._filter(r, spider))
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/mnt/home/kxs997/anaconda3/lib/python3.11/site-packages/scrapy/core/spidermw.py", line 104, in process_sync
#     for r in iterable:
#   File "/mnt/home/kxs997/anaconda3/lib/python3.11/site-packages/scrapy/spidermiddlewares/referer.py", line 353, in <genexpr>
#     return (self._set_referer(r, response) for r in result or ())
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/mnt/home/kxs997/anaconda3/lib/python3.11/site-packages/scrapy/core/spidermw.py", line 104, in process_sync
#     for r in iterable:
#   File "/mnt/home/kxs997/anaconda3/lib/python3.11/site-packages/scrapy/spidermiddlewares/urllength.py", line 27, in <genexpr>
#     return (r for r in result or () if self._filter(r, spider))
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/mnt/home/kxs997/anaconda3/lib/python3.11/site-packages/scrapy/core/spidermw.py", line 104, in process_sync
#     for r in iterable:
#   File "/mnt/home/kxs997/anaconda3/lib/python3.11/site-packages/scrapy/spidermiddlewares/depth.py", line 31, in <genexpr>
#     return (r for r in result or () if self._filter(r, response, spider))
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/mnt/home/kxs997/anaconda3/lib/python3.11/site-packages/scrapy/core/spidermw.py", line 104, in process_sync
#     for r in iterable:
#   File "/tmp/ipykernel_18287/315165690.py", line 32, in parse
#     rating = item.xpath('//p[contains(@class, "star-rating')[0].extract()
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/mnt/home/kxs997/anaconda3/lib/python3.11/site-packages/parsel/selector.py", line 260, in xpath
#     six.reraise(ValueError, ValueError(msg), sys.exc_info()[2])
#   File "/mnt/home/kxs997/anaconda3/lib/python3.11/site-packages/six.py", line 718, in reraise
#     raise value.with_traceback(tb)
#   File "/mnt/home/kxs997/anaconda3/lib/python3.11/site-packages/parsel/selector.py", line 254, in xpath
#     result = xpathev(query, namespaces=nsp,
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "src/lxml/etree.pyx", line 1599, in lxml.etree._Element.xpath
#   File "src/lxml/xpath.pxi", line 305, in lxml.etree.XPathElementEvaluator.__call__
#   File "src/lxml/xpath.pxi", line 225, in lxml.etree._XPathEvaluatorBase._handle_result
# ValueError: XPath error: Unfinished literal in //p[contains(@class, "star-rating
# 2023-11-14 11:25:46 [scrapy.core.scraper] ERROR: Spider error processing <GET http://books.toscrape.com/catalogue/category/books/classics_6/index.html> (referer: None)
# Traceback (most recent call last):
#   File "/mnt/home/kxs997/anaconda3/lib/python3.11/site-packages/parsel/selector.py", line 254, in xpath
#     result = xpathev(query, namespaces=nsp,
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "src/lxml/etree.pyx", line 1599, in lxml.etree._Element.xpath
#   File "src/lxml/xpath.pxi", line 305, in lxml.etree.XPathElementEvaluator.__call__
#   File "src/lxml/xpath.pxi", line 225, in lxml.etree._XPathEvaluatorBase._handle_result
# lxml.etree.XPathEvalError: Unfinished literal
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/mnt/home/kxs997/anaconda3/lib/python3.11/site-packages/scrapy/utils/defer.py", line 257, in iter_errback
#     yield next(it)
#           ^^^^^^^^
#   File "/mnt/home/kxs997/anaconda3/lib/python3.11/site-packages/scrapy/utils/python.py", line 312, in __next__
#     return next(self.data)
#            ^^^^^^^^^^^^^^^
#   File "/mnt/home/kxs997/anaconda3/lib/python3.11/site-packages/scrapy/utils/python.py", line 312, in __next__
#     return next(self.data)
#            ^^^^^^^^^^^^^^^
#   File "/mnt/home/kxs997/anaconda3/lib/python3.11/site-packages/scrapy/core/spidermw.py", line 104, in process_sync
#     for r in iterable:
#   File "/mnt/home/kxs997/anaconda3/lib/python3.11/site-packages/scrapy/spidermiddlewares/offsite.py", line 28, in <genexpr>
#     return (r for r in result or () if self._filter(r, spider))
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/mnt/home/kxs997/anaconda3/lib/python3.11/site-packages/scrapy/core/spidermw.py", line 104, in process_sync
#     for r in iterable:
#   File "/mnt/home/kxs997/anaconda3/lib/python3.11/site-packages/scrapy/spidermiddlewares/referer.py", line 353, in <genexpr>
#     return (self._set_referer(r, response) for r in result or ())
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/mnt/home/kxs997/anaconda3/lib/python3.11/site-packages/scrapy/core/spidermw.py", line 104, in process_sync
#     for r in iterable:
#   File "/mnt/home/kxs997/anaconda3/lib/python3.11/site-packages/scrapy/spidermiddlewares/urllength.py", line 27, in <genexpr>
#     return (r for r in result or () if self._filter(r, spider))
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/mnt/home/kxs997/anaconda3/lib/python3.11/site-packages/scrapy/core/spidermw.py", line 104, in process_sync
#     for r in iterable:
#   File "/mnt/home/kxs997/anaconda3/lib/python3.11/site-packages/scrapy/spidermiddlewares/depth.py", line 31, in <genexpr>
#     return (r for r in result or () if self._filter(r, response, spider))
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/mnt/home/kxs997/anaconda3/lib/python3.11/site-packages/scrapy/core/spidermw.py", line 104, in process_sync
#     for r in iterable:
#   File "/tmp/ipykernel_18287/315165690.py", line 32, in parse
#     rating = item.xpath('//p[contains(@class, "star-rating')[0].extract()
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/mnt/home/kxs997/anaconda3/lib/python3.11/site-packages/parsel/selector.py", line 260, in xpath
#     six.reraise(ValueError, ValueError(msg), sys.exc_info()[2])
#   File "/mnt/home/kxs997/anaconda3/lib/python3.11/site-packages/six.py", line 718, in reraise
#     raise value.with_traceback(tb)
#   File "/mnt/home/kxs997/anaconda3/lib/python3.11/site-packages/parsel/selector.py", line 254, in xpath
#     result = xpathev(query, namespaces=nsp,
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "src/lxml/etree.pyx", line 1599, in lxml.etree._Element.xpath
#   File "src/lxml/xpath.pxi", line 305, in lxml.etree.XPathElementEvaluator.__call__
#   File "src/lxml/xpath.pxi", line 225, in lxml.etree._XPathEvaluatorBase._handle_result
# ValueError: XPath error: Unfinished literal in //p[contains(@class, "star-rating
# 2023-11-14 11:25:46 [scrapy.core.engine] INFO: Closing spider (finished)
# 2023-11-14 11:25:46 [scrapy.statscollectors] INFO: Dumping Scrapy stats:
# {'downloader/request_bytes': 2486,
#  'downloader/request_count': 9,
#  'downloader/request_method_count/GET': 9,
#  'downloader/response_bytes': 45389,
#  'downloader/response_count': 9,
#  'downloader/response_status_count/200': 9,
#  'elapsed_time_seconds': 0.338311,
#  'finish_reason': 'finished',
#  'finish_time': datetime.datetime(2023, 11, 14, 16, 25, 46, 104833),
#  'httpcompression/response_bytes': 419249,
#  'httpcompression/response_count': 9,
#  'log_count/DEBUG': 10,
#  'log_count/ERROR': 9,
#  'log_count/INFO': 10,
#  'log_count/WARNING': 1,
#  'memusage/max': 246341632,
#  'memusage/startup': 246341632,
#  'response_received_count': 9,
#  'scheduler/dequeued': 9,
#  'scheduler/dequeued/memory': 9,
#  'scheduler/enqueued': 9,
#  'scheduler/enqueued/memory': 9,
#  'spider_exceptions/ValueError': 9,
#  'start_time': datetime.datetime(2023, 11, 14, 16, 25, 45, 766522)}
# 2023-11-14 11:25:46 [scrapy.core.engine] INFO: Spider closed (finished)
# Processing:http://books.toscrape.com/catalogue/category/books/travel_2/index.html
# Processing:http://books.toscrape.com/catalogue/category/books/mystery_3/index.html
# Processing:http://books.toscrape.com/catalogue/category/books/womens-fiction_9/index.html
# Processing:http://books.toscrape.com/catalogue/category/books/historical-fiction_4/index.html
# Processing:http://books.toscrape.com/catalogue/category/books/romance_8/index.html
# Processing:http://books.toscrape.com/catalogue/category/books/philosophy_7/index.html
# Processing:http://books.toscrape.com/catalogue/category/books/sequential-art_5/index.html
# Processing:http://books.toscrape.com/catalogue/category/books/fiction_10/index.html
# Processing:http://books.toscrape.com/catalogue/category/books/classics_6/index.html

# %%
import scrapy
import pandas as pd
from scrapy.crawler import CrawlerProcess


class BookRatings(scrapy.Spider):
    name = "BookRatings"
    allowed_domains = ['books.toscrape.com']
    start_urls = [
        'http://books.toscrape.com/catalogue/category/books/travel_2/index.html',
        'http://books.toscrape.com/catalogue/category/books/mystery_3/index.html',
        'http://books.toscrape.com/catalogue/category/books/historical-fiction_4/index.html',
        'http://books.toscrape.com/catalogue/category/books/sequential-art_5/index.html',
        'http://books.toscrape.com/catalogue/category/books/classics_6/index.html',
        'http://books.toscrape.com/catalogue/category/books/philosophy_7/index.html',
        'http://books.toscrape.com/catalogue/category/books/romance_8/index.html',
        'http://books.toscrape.com/catalogue/category/books/womens-fiction_9/index.html',
        'http://books.toscrape.com/catalogue/category/books/fiction_10/index.html'
    ]

    def parse(self, response):
        print("Processing: " + response.url)

        url = response.url

        items = response.xpath("//ol/li")
        books = []

        for item in items:
            name = str(item.xpath('.//h3/a/text()').extract()).strip("]").strip("[").strip("'").strip("\"")
            price = item.xpath('.//div[@class="product_price"]/p/text()')[0].extract().strip()
            rating = item.xpath('.//p[contains(@class, "star-rating")]/@class').extract_first()
            link = str(item.xpath('.//h3/a/@href').extract()).strip("]").strip("[").strip("'").strip("\"").replace("../../../", "http://books.toscrape.com/catalogue/")

            books.append([url, name, price, rating, link])

        df = pd.DataFrame(books, columns=['url', 'book name', 'price', 'rating', 'link'])

        # Mapping for star ratings
        number_mapping = {
            'star-rating One': 1,
            'star-rating Two': 2,
            'star-rating Three': 3,
            'star-rating Four': 4,
            'star-rating Five': 5
        }
        df["rating"] = df["rating"].apply(lambda x: number_mapping.get(x.split()[-1]))

        # Save DataFrame to CSV
        df.to_csv("book-ratings-" + url.split("/")[6] + ".csv", sep=',', encoding='utf-8', mode='w', index=False)
        
        yield df


process = CrawlerProcess()
process.crawl(BookRatings)
process.start()
# Out:
# 2023-11-14 11:34:26 [scrapy.utils.log] INFO: Scrapy 2.8.0 started (bot: scrapybot)
# 2023-11-14 11:34:26 [scrapy.utils.log] INFO: Versions: lxml 4.9.1.0, libxml2 2.9.14, cssselect 1.1.0, parsel 1.6.0, w3lib 1.21.0, Twisted 22.10.0, Python 3.11.3 (main, Apr 19 2023, 23:54:32) [GCC 11.2.0], pyOpenSSL 23.0.0 (OpenSSL 1.1.1w  11 Sep 2023), cryptography 39.0.1, Platform Linux-5.15.0-86-generic-x86_64-with-glibc2.31
# 2023-11-14 11:34:26 [scrapy.crawler] INFO: Overridden settings:
# {}
# 2023-11-14 11:34:26 [py.warnings] WARNING: /mnt/home/kxs997/anaconda3/lib/python3.11/site-packages/scrapy/utils/request.py:232: ScrapyDeprecationWarning: '2.6' is a deprecated value for the 'REQUEST_FINGERPRINTER_IMPLEMENTATION' setting.
#
# It is also the default value. In other words, it is normal to get this warning if you have not defined a value for the 'REQUEST_FINGERPRINTER_IMPLEMENTATION' setting. This is so for backward compatibility reasons, but it will change in a future version of Scrapy.
#
# See the documentation of the 'REQUEST_FINGERPRINTER_IMPLEMENTATION' setting for information on how to handle this deprecation.
#   return cls(crawler)
#
# 2023-11-14 11:34:26 [scrapy.utils.log] DEBUG: Using reactor: twisted.internet.epollreactor.EPollReactor
# 2023-11-14 11:34:26 [scrapy.extensions.telnet] INFO: Telnet Password: 6e5e917bd5511c12
# 2023-11-14 11:34:26 [scrapy.middleware] INFO: Enabled extensions:
# ['scrapy.extensions.corestats.CoreStats',
#  'scrapy.extensions.telnet.TelnetConsole',
#  'scrapy.extensions.memusage.MemoryUsage',
#  'scrapy.extensions.logstats.LogStats']
# 2023-11-14 11:34:26 [scrapy.middleware] INFO: Enabled downloader middlewares:
# ['scrapy.downloadermiddlewares.httpauth.HttpAuthMiddleware',
#  'scrapy.downloadermiddlewares.downloadtimeout.DownloadTimeoutMiddleware',
#  'scrapy.downloadermiddlewares.defaultheaders.DefaultHeadersMiddleware',
#  'scrapy.downloadermiddlewares.useragent.UserAgentMiddleware',
#  'scrapy.downloadermiddlewares.retry.RetryMiddleware',
#  'scrapy.downloadermiddlewares.redirect.MetaRefreshMiddleware',
#  'scrapy.downloadermiddlewares.httpcompression.HttpCompressionMiddleware',
#  'scrapy.downloadermiddlewares.redirect.RedirectMiddleware',
#  'scrapy.downloadermiddlewares.cookies.CookiesMiddleware',
#  'scrapy.downloadermiddlewares.httpproxy.HttpProxyMiddleware',
#  'scrapy.downloadermiddlewares.stats.DownloaderStats']
# 2023-11-14 11:34:26 [scrapy.middleware] INFO: Enabled spider middlewares:
# ['scrapy.spidermiddlewares.httperror.HttpErrorMiddleware',
#  'scrapy.spidermiddlewares.offsite.OffsiteMiddleware',
#  'scrapy.spidermiddlewares.referer.RefererMiddleware',
#  'scrapy.spidermiddlewares.urllength.UrlLengthMiddleware',
#  'scrapy.spidermiddlewares.depth.DepthMiddleware']
# 2023-11-14 11:34:26 [scrapy.middleware] INFO: Enabled item pipelines:
# []
# 2023-11-14 11:34:26 [scrapy.core.engine] INFO: Spider opened
# 2023-11-14 11:34:26 [scrapy.extensions.logstats] INFO: Crawled 0 pages (at 0 pages/min), scraped 0 items (at 0 items/min)
# 2023-11-14 11:34:26 [scrapy.extensions.telnet] INFO: Telnet console listening on 127.0.0.1:6023
# 2023-11-14 11:34:26 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://books.toscrape.com/catalogue/category/books/travel_2/index.html> (referer: None)
# 2023-11-14 11:34:26 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://books.toscrape.com/catalogue/category/books/womens-fiction_9/index.html> (referer: None)
# 2023-11-14 11:34:26 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://books.toscrape.com/catalogue/category/books/classics_6/index.html> (referer: None)
# 2023-11-14 11:34:26 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://books.toscrape.com/catalogue/category/books/mystery_3/index.html> (referer: None)
# 2023-11-14 11:34:26 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://books.toscrape.com/catalogue/category/books/historical-fiction_4/index.html> (referer: None)
# 2023-11-14 11:34:26 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://books.toscrape.com/catalogue/category/books/philosophy_7/index.html> (referer: None)
# 2023-11-14 11:34:26 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://books.toscrape.com/catalogue/category/books/sequential-art_5/index.html> (referer: None)
# 2023-11-14 11:34:26 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://books.toscrape.com/catalogue/category/books/romance_8/index.html> (referer: None)
# 2023-11-14 11:34:26 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://books.toscrape.com/catalogue/category/books/fiction_10/index.html> (referer: None)
# 2023-11-14 11:34:27 [scrapy.core.scraper] ERROR: Spider must return request, item, or None, got 'DataFrame' in <GET http://books.toscrape.com/catalogue/category/books/travel_2/index.html>
# 2023-11-14 11:34:27 [scrapy.core.scraper] ERROR: Spider must return request, item, or None, got 'DataFrame' in <GET http://books.toscrape.com/catalogue/category/books/womens-fiction_9/index.html>
# 2023-11-14 11:34:27 [scrapy.core.scraper] ERROR: Spider must return request, item, or None, got 'DataFrame' in <GET http://books.toscrape.com/catalogue/category/books/classics_6/index.html>
# 2023-11-14 11:34:27 [scrapy.core.scraper] ERROR: Spider must return request, item, or None, got 'DataFrame' in <GET http://books.toscrape.com/catalogue/category/books/mystery_3/index.html>
# 2023-11-14 11:34:27 [scrapy.core.scraper] ERROR: Spider must return request, item, or None, got 'DataFrame' in <GET http://books.toscrape.com/catalogue/category/books/historical-fiction_4/index.html>
# Processing: http://books.toscrape.com/catalogue/category/books/travel_2/index.html
# Processing: http://books.toscrape.com/catalogue/category/books/womens-fiction_9/index.html
# Processing: http://books.toscrape.com/catalogue/category/books/classics_6/index.html
# Processing: http://books.toscrape.com/catalogue/category/books/mystery_3/index.html
# Processing: http://books.toscrape.com/catalogue/category/books/historical-fiction_4/index.html
# Processing: http://books.toscrape.com/catalogue/category/books/philosophy_7/index.html
# 2023-11-14 11:34:27 [scrapy.core.scraper] ERROR: Spider must return request, item, or None, got 'DataFrame' in <GET http://books.toscrape.com/catalogue/category/books/philosophy_7/index.html>
# 2023-11-14 11:34:27 [scrapy.core.scraper] ERROR: Spider must return request, item, or None, got 'DataFrame' in <GET http://books.toscrape.com/catalogue/category/books/sequential-art_5/index.html>
# 2023-11-14 11:34:27 [scrapy.core.scraper] ERROR: Spider must return request, item, or None, got 'DataFrame' in <GET http://books.toscrape.com/catalogue/category/books/romance_8/index.html>
# 2023-11-14 11:34:27 [scrapy.core.scraper] ERROR: Spider must return request, item, or None, got 'DataFrame' in <GET http://books.toscrape.com/catalogue/category/books/fiction_10/index.html>
# 2023-11-14 11:34:27 [scrapy.core.engine] INFO: Closing spider (finished)
# 2023-11-14 11:34:27 [scrapy.statscollectors] INFO: Dumping Scrapy stats:
# {'downloader/request_bytes': 2486,
#  'downloader/request_count': 9,
#  'downloader/request_method_count/GET': 9,
#  'downloader/response_bytes': 45370,
#  'downloader/response_count': 9,
#  'downloader/response_status_count/200': 9,
#  'elapsed_time_seconds': 0.510452,
#  'finish_reason': 'finished',
#  'finish_time': datetime.datetime(2023, 11, 14, 16, 34, 27, 270300),
#  'httpcompression/response_bytes': 419249,
#  'httpcompression/response_count': 9,
#  'log_count/DEBUG': 10,
#  'log_count/ERROR': 9,
#  'log_count/INFO': 10,
#  'log_count/WARNING': 1,
#  'memusage/max': 246341632,
#  'memusage/startup': 246341632,
#  'response_received_count': 9,
#  'scheduler/dequeued': 9,
#  'scheduler/dequeued/memory': 9,
#  'scheduler/enqueued': 9,
#  'scheduler/enqueued/memory': 9,
#  'start_time': datetime.datetime(2023, 11, 14, 16, 34, 26, 759848)}
# 2023-11-14 11:34:27 [scrapy.core.engine] INFO: Spider closed (finished)
# Processing: http://books.toscrape.com/catalogue/category/books/sequential-art_5/index.html
# Processing: http://books.toscrape.com/catalogue/category/books/romance_8/index.html
# Processing: http://books.toscrape.com/catalogue/category/books/fiction_10/index.html

# %%
# !pip install -U spacy
# !python -m spacy download en_core_web_lg
# Out:
# Requirement already satisfied: spacy in /mnt/home/kxs997/anaconda3/lib/python3.11/site-packages (3.7.2)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in /mnt/home/kxs997/anaconda3/lib/python3.11/site-packages (from spacy) (3.0.12)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in /mnt/home/kxs997/anaconda3/lib/python3.11/site-packages (from spacy) (1.0.5)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /mnt/home/kxs997/anaconda3/lib/python3.11/site-packages (from spacy) (1.0.10)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /mnt/home/kxs997/anaconda3/lib/python3.11/site-packages (from spacy) (2.0.8)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /mnt/home/kxs997/anaconda3/lib/python3.11/site-packages (from spacy) (3.0.9)
# Requirement already satisfied: thinc<8.3.0,>=8.1.8 in /mnt/home/kxs997/anaconda3/lib/python3.11/site-packages (from spacy) (8.2.1)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in /mnt/home/kxs997/anaconda3/lib/python3.11/site-packages (from spacy) (1.1.2)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in /mnt/home/kxs997/anaconda3/lib/python3.11/site-packages (from spacy) (2.4.8)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in /mnt/home/kxs997/anaconda3/lib/python3.11/site-packages (from spacy) (2.0.10)
# Requirement already satisfied: weasel<0.4.0,>=0.1.0 in /mnt/home/kxs997/anaconda3/lib/python3.11/site-packages (from spacy) (0.3.4)
# Requirement already satisfied: typer<0.10.0,>=0.3.0 in /mnt/home/kxs997/anaconda3/lib/python3.11/site-packages (from spacy) (0.9.0)
# Requirement already satisfied: smart-open<7.0.0,>=5.2.1 in /mnt/home/kxs997/anaconda3/lib/python3.11/site-packages (from spacy) (5.2.1)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /mnt/home/kxs997/anaconda3/lib/python3.11/site-packages (from spacy) (4.65.0)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /mnt/home/kxs997/anaconda3/lib/python3.11/site-packages (from spacy) (2.29.0)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4 in /mnt/home/kxs997/anaconda3/lib/python3.11/site-packages (from spacy) (1.10.12)
# Requirement already satisfied: jinja2 in /mnt/home/kxs997/anaconda3/lib/python3.11/site-packages (from spacy) (3.1.2)
# Requirement already satisfied: setuptools in /mnt/home/kxs997/anaconda3/lib/python3.11/site-packages (from spacy) (67.8.0)
# Requirement already satisfied: packaging>=20.0 in /mnt/home/kxs997/anaconda3/lib/python3.11/site-packages (from spacy) (23.0)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in /mnt/home/kxs997/anaconda3/lib/python3.11/site-packages (from spacy) (3.3.0)
# Requirement already satisfied: numpy>=1.19.0 in /mnt/home/kxs997/anaconda3/lib/python3.11/site-packages (from spacy) (1.24.3)
# Requirement already satisfied: typing-extensions>=4.2.0 in /mnt/home/kxs997/anaconda3/lib/python3.11/site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy) (4.6.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /mnt/home/kxs997/anaconda3/lib/python3.11/site-packages (from requests<3.0.0,>=2.13.0->spacy) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in /mnt/home/kxs997/anaconda3/lib/python3.11/site-packages (from requests<3.0.0,>=2.13.0->spacy) (3.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /mnt/home/kxs997/anaconda3/lib/python3.11/site-packages (from requests<3.0.0,>=2.13.0->spacy) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in /mnt/home/kxs997/anaconda3/lib/python3.11/site-packages (from requests<3.0.0,>=2.13.0->spacy) (2023.7.22)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in /mnt/home/kxs997/anaconda3/lib/python3.11/site-packages (from thinc<8.3.0,>=8.1.8->spacy) (0.7.11)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in /mnt/home/kxs997/anaconda3/lib/python3.11/site-packages (from thinc<8.3.0,>=8.1.8->spacy) (0.1.3)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in /mnt/home/kxs997/anaconda3/lib/python3.11/site-packages (from typer<0.10.0,>=0.3.0->spacy) (8.0.4)
# Requirement already satisfied: cloudpathlib<0.17.0,>=0.7.0 in /mnt/home/kxs997/anaconda3/lib/python3.11/site-packages (from weasel<0.4.0,>=0.1.0->spacy) (0.16.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /mnt/home/kxs997/anaconda3/lib/python3.11/site-packages (from jinja2->spacy) (2.1.1)
# Collecting en-core-web-lg==3.7.0
#   Downloading https://github.com/explosion/spacy-models/releases/download/en_core_web_lg-3.7.0/en_core_web_lg-3.7.0-py3-none-any.whl (587.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 587.7/587.7 MB 348.5 kB/s eta 0:00:0000:0100:28
# Requirement already satisfied: spacy<3.8.0,>=3.7.0 in /mnt/home/kxs997/anaconda3/lib/python3.11/site-packages (from en-core-web-lg==3.7.0) (3.7.2)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in /mnt/home/kxs997/anaconda3/lib/python3.11/site-packages (from spacy<3.8.0,>=3.7.0->en-core-web-lg==3.7.0) (3.0.12)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in /mnt/home/kxs997/anaconda3/lib/python3.11/site-packages (from spacy<3.8.0,>=3.7.0->en-core-web-lg==3.7.0) (1.0.5)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /mnt/home/kxs997/anaconda3/lib/python3.11/site-packages (from spacy<3.8.0,>=3.7.0->en-core-web-lg==3.7.0) (1.0.10)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /mnt/home/kxs997/anaconda3/lib/python3.11/site-packages (from spacy<3.8.0,>=3.7.0->en-core-web-lg==3.7.0) (2.0.8)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /mnt/home/kxs997/anaconda3/lib/python3.11/site-packages (from spacy<3.8.0,>=3.7.0->en-core-web-lg==3.7.0) (3.0.9)
# Requirement already satisfied: thinc<8.3.0,>=8.1.8 in /mnt/home/kxs997/anaconda3/lib/python3.11/site-packages (from spacy<3.8.0,>=3.7.0->en-core-web-lg==3.7.0) (8.2.1)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in /mnt/home/kxs997/anaconda3/lib/python3.11/site-packages (from spacy<3.8.0,>=3.7.0->en-core-web-lg==3.7.0) (1.1.2)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in /mnt/home/kxs997/anaconda3/lib/python3.11/site-packages (from spacy<3.8.0,>=3.7.0->en-core-web-lg==3.7.0) (2.4.8)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in /mnt/home/kxs997/anaconda3/lib/python3.11/site-packages (from spacy<3.8.0,>=3.7.0->en-core-web-lg==3.7.0) (2.0.10)
# Requirement already satisfied: weasel<0.4.0,>=0.1.0 in /mnt/home/kxs997/anaconda3/lib/python3.11/site-packages (from spacy<3.8.0,>=3.7.0->en-core-web-lg==3.7.0) (0.3.4)
# Requirement already satisfied: typer<0.10.0,>=0.3.0 in /mnt/home/kxs997/anaconda3/lib/python3.11/site-packages (from spacy<3.8.0,>=3.7.0->en-core-web-lg==3.7.0) (0.9.0)
# Requirement already satisfied: smart-open<7.0.0,>=5.2.1 in /mnt/home/kxs997/anaconda3/lib/python3.11/site-packages (from spacy<3.8.0,>=3.7.0->en-core-web-lg==3.7.0) (5.2.1)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /mnt/home/kxs997/anaconda3/lib/python3.11/site-packages (from spacy<3.8.0,>=3.7.0->en-core-web-lg==3.7.0) (4.65.0)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /mnt/home/kxs997/anaconda3/lib/python3.11/site-packages (from spacy<3.8.0,>=3.7.0->en-core-web-lg==3.7.0) (2.29.0)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4 in /mnt/home/kxs997/anaconda3/lib/python3.11/site-packages (from spacy<3.8.0,>=3.7.0->en-core-web-lg==3.7.0) (1.10.12)
# Requirement already satisfied: jinja2 in /mnt/home/kxs997/anaconda3/lib/python3.11/site-packages (from spacy<3.8.0,>=3.7.0->en-core-web-lg==3.7.0) (3.1.2)
# Requirement already satisfied: setuptools in /mnt/home/kxs997/anaconda3/lib/python3.11/site-packages (from spacy<3.8.0,>=3.7.0->en-core-web-lg==3.7.0) (67.8.0)
# Requirement already satisfied: packaging>=20.0 in /mnt/home/kxs997/anaconda3/lib/python3.11/site-packages (from spacy<3.8.0,>=3.7.0->en-core-web-lg==3.7.0) (23.0)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in /mnt/home/kxs997/anaconda3/lib/python3.11/site-packages (from spacy<3.8.0,>=3.7.0->en-core-web-lg==3.7.0) (3.3.0)
# Requirement already satisfied: numpy>=1.19.0 in /mnt/home/kxs997/anaconda3/lib/python3.11/site-packages (from spacy<3.8.0,>=3.7.0->en-core-web-lg==3.7.0) (1.24.3)
# Requirement already satisfied: typing-extensions>=4.2.0 in /mnt/home/kxs997/anaconda3/lib/python3.11/site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy<3.8.0,>=3.7.0->en-core-web-lg==3.7.0) (4.6.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /mnt/home/kxs997/anaconda3/lib/python3.11/site-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.0->en-core-web-lg==3.7.0) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in /mnt/home/kxs997/anaconda3/lib/python3.11/site-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.0->en-core-web-lg==3.7.0) (3.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /mnt/home/kxs997/anaconda3/lib/python3.11/site-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.0->en-core-web-lg==3.7.0) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in /mnt/home/kxs997/anaconda3/lib/python3.11/site-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.0->en-core-web-lg==3.7.0) (2023.7.22)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in /mnt/home/kxs997/anaconda3/lib/python3.11/site-packages (from thinc<8.3.0,>=8.1.8->spacy<3.8.0,>=3.7.0->en-core-web-lg==3.7.0) (0.7.11)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in /mnt/home/kxs997/anaconda3/lib/python3.11/site-packages (from thinc<8.3.0,>=8.1.8->spacy<3.8.0,>=3.7.0->en-core-web-lg==3.7.0) (0.1.3)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in /mnt/home/kxs997/anaconda3/lib/python3.11/site-packages (from typer<0.10.0,>=0.3.0->spacy<3.8.0,>=3.7.0->en-core-web-lg==3.7.0) (8.0.4)
# Requirement already satisfied: cloudpathlib<0.17.0,>=0.7.0 in /mnt/home/kxs997/anaconda3/lib/python3.11/site-packages (from weasel<0.4.0,>=0.1.0->spacy<3.8.0,>=3.7.0->en-core-web-lg==3.7.0) (0.16.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /mnt/home/kxs997/anaconda3/lib/python3.11/site-packages (from jinja2->spacy<3.8.0,>=3.7.0->en-core-web-lg==3.7.0) (2.1.1)
# Installing collected packages: en-core-web-lg
# Successfully installed en-core-web-lg-3.7.0
# ✔ Download and installation successful
# You can now load the package via spacy.load('en_core_web_lg')

# %%
import spacy
# Load the en_core_web_lg model
lg_nlp = spacy.load("en_core_web_lg")

# Print the number of words in the model's vocabulary
print("Number of words: ", lg_nlp.meta["vectors"]["vectors"], "\n")

# Print the dimensions of word vectors in en_core_web_lg model
print("Dimension of word vectors: ", lg_nlp.meta["vectors"]["width"])
# Out:
# Number of words:  514157
#
# Dimension of word vectors:  300

# %%
fname = "/mnt/home/kxs997/Downloads/digital-revolution.txt"
text_file = open(fname, 'r')
texts = text_file.readlines()

# %%
# Generating a documents list of all Doc containers
documents = [lg_nlp(text) for text in texts]

# Iterate through documents and append sentences in each doc to the sentences list
sentences = []
for doc in documents:
    sentences.extend([s for s in doc.sents])

# Find number of sentences per each doc container
print("Number of sentences in each doc container: ")
print([len(s) for s in sentences])
# Out:
# Number of sentences in each doc container:
# [7, 6, 5, 21, 17, 24, 28, 38, 30, 47, 24, 22, 28, 64, 41, 28, 19, 36, 30, 55, 17, 55]

# %%
from spacy import displacy

# Visualize spaCy's guess at the named entities in the document
for doc in documents:
    displacy.render(doc, style="ent")

# Visualize spaCy's guess at the dependencies in the document
for doc in documents:
    displacy.render(doc, style="dep")

for doc in documents:
    print([(ent.text, ent.label_) for ent in doc.ents])
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     The Essential Components of Digital Revolution
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  <br></div></span>
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">By
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Tomas Chamorro-Premuzic
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# <br></div></span>
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     November 23, 2021
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# <br></div></span>
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">The digital revolution forced every organization to reinvent itself, or at least rethink how it goes about doing business. Most large companies have invested substantial cash in what is generally labelled “digital transformation.” While those investments are projected to top
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     $6.8 trillion
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">MONEY</span>
# </mark>
#  by
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     2023
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# , they’re often made without seeing clear benefits or ROI. Although these failures have multiple causes, they are generally the result of underestimating the various steps or stages required to successfully execute a transformation agenda.<br></div></span>
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">For example, common errors include the naïve assumption that by simply buying technology — or investing in any of the fancy tools or shiny new objects of the booming tech market — organizations will somehow transform. But even the best technology will go to waste if you don’t have the right processes, culture, or talent in place to take advantage of it. As
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Stanford
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# ’s
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Erik Brynjolfsson
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  noted, a major reason for the lack of productivity gains from new technologies, including
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     AI
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# , is the failure to invest in skills — especially the lack of re-skilling and upskilling once employees are in your workforce. I once managed to persuade my grandfather to buy a cellphone; he never even bothered to take it out of the box. For many organizations, persuading experienced employees or senior managers to deploy new tech tools is a rather similar experience.<br></div></span>
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">It’s problematic when companies decide to embark on a digital transformation agenda without having a clear definition, let alone vision, for what it means. Although every organization is unique, and there are salient differences between types of businesses, industries, and cultures, the fundamental meaning of transformation is not about replacing old technologies with new ones, or capturing high volumes of data, or hiring an army of data scientists, or trying to copy some of the things
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Google
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  or
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Amazon
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  do. In fact, the essence of digital transformation is to become a data-driven organization, ensuring that key decisions, actions, and processes are strongly influenced by data-driven insights, rather than by human intuition. In other words, you will only transform when you have managed to change how people behave, and how things are done in your organization.<br></div></span>
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">In short, the critical part of digital transformation is not “digital” but “transformation.” Our world has changed dramatically in
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     the past two decades
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# , and adapting your organization to these changes cannot be achieved
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     overnight
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">TIME</span>
# </mark>
# , or simply by buying new technologies, or collecting more data. What is needed is a shift in mindset, culture, and talent, including upskilling and re-skilling your workforce so that they are future-ready. That said, there is
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     one
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#  thing that hasn’t changed — namely the fact that all of this is just the new version of an old task or challenge every leader has always faced throughout human history: to prepare their teams and organizations for the future, and create a better future. Nobody is truly a leader if they are in charge and keep things as they are. Leadership is always an argument with the past, with tradition — it is the essential task of leaders to create a bridge between the past and the future, and in that sense digital transformation is not an exception to the rule, but the name we give to
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     today
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# ’s bridge.<br></div></span>
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="9ca439b0648047cf825465029562d24c-0" class="displacy" width="1275" height="312.0" direction="ltr" style="max-width: none; height: 312.0px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="222.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">The</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="222.0">
#     <tspan class="displacy-word" fill="currentColor" x="225">Essential</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="225">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="222.0">
#     <tspan class="displacy-word" fill="currentColor" x="400">Components</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="400">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="222.0">
#     <tspan class="displacy-word" fill="currentColor" x="575">of</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="575">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="222.0">
#     <tspan class="displacy-word" fill="currentColor" x="750">Digital</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="750">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="222.0">
#     <tspan class="displacy-word" fill="currentColor" x="925">Revolution</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="925">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="222.0">
#     <tspan class="displacy-word" fill="currentColor" x="1100">
# </tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1100">SPACE</tspan>
# </text>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-9ca439b0648047cf825465029562d24c-0-0" stroke-width="2px" d="M70,177.0 C70,2.0 400.0,2.0 400.0,177.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-9ca439b0648047cf825465029562d24c-0-0" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">det</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M70,179.0 L62,167.0 78,167.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-9ca439b0648047cf825465029562d24c-0-1" stroke-width="2px" d="M245,177.0 C245,89.5 395.0,89.5 395.0,177.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-9ca439b0648047cf825465029562d24c-0-1" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">compound</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M245,179.0 L237,167.0 253,167.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-9ca439b0648047cf825465029562d24c-0-2" stroke-width="2px" d="M420,177.0 C420,89.5 570.0,89.5 570.0,177.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-9ca439b0648047cf825465029562d24c-0-2" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">prep</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M570.0,179.0 L578.0,167.0 562.0,167.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-9ca439b0648047cf825465029562d24c-0-3" stroke-width="2px" d="M770,177.0 C770,89.5 920.0,89.5 920.0,177.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-9ca439b0648047cf825465029562d24c-0-3" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">compound</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M770,179.0 L762,167.0 778,167.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-9ca439b0648047cf825465029562d24c-0-4" stroke-width="2px" d="M595,177.0 C595,2.0 925.0,2.0 925.0,177.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-9ca439b0648047cf825465029562d24c-0-4" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">pobj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M925.0,179.0 L933.0,167.0 917.0,167.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-9ca439b0648047cf825465029562d24c-0-5" stroke-width="2px" d="M945,177.0 C945,89.5 1095.0,89.5 1095.0,177.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-9ca439b0648047cf825465029562d24c-0-5" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">dep</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M1095.0,179.0 L1103.0,167.0 1087.0,167.0" fill="currentColor"/>
# </g>
# </svg></span>
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="c7917bb34a934ec0950eb52c0a284bef-0" class="displacy" width="925" height="399.5" direction="ltr" style="max-width: none; height: 399.5px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="309.5">
#     <tspan class="displacy-word" fill="currentColor" x="50">By</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="309.5">
#     <tspan class="displacy-word" fill="currentColor" x="225">Tomas</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="225">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="309.5">
#     <tspan class="displacy-word" fill="currentColor" x="400">Chamorro-</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="400">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="309.5">
#     <tspan class="displacy-word" fill="currentColor" x="575">Premuzic</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="575">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="309.5">
#     <tspan class="displacy-word" fill="currentColor" x="750">
# </tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="750">SPACE</tspan>
# </text>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-c7917bb34a934ec0950eb52c0a284bef-0-0" stroke-width="2px" d="M245,264.5 C245,177.0 390.0,177.0 390.0,264.5" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-c7917bb34a934ec0950eb52c0a284bef-0-0" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">compound</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M245,266.5 L237,254.5 253,254.5" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-c7917bb34a934ec0950eb52c0a284bef-0-1" stroke-width="2px" d="M70,264.5 C70,89.5 395.0,89.5 395.0,264.5" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-c7917bb34a934ec0950eb52c0a284bef-0-1" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">pobj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M395.0,266.5 L403.0,254.5 387.0,254.5" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-c7917bb34a934ec0950eb52c0a284bef-0-2" stroke-width="2px" d="M70,264.5 C70,2.0 575.0,2.0 575.0,264.5" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-c7917bb34a934ec0950eb52c0a284bef-0-2" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">pobj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M575.0,266.5 L583.0,254.5 567.0,254.5" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-c7917bb34a934ec0950eb52c0a284bef-0-3" stroke-width="2px" d="M595,264.5 C595,177.0 740.0,177.0 740.0,264.5" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-c7917bb34a934ec0950eb52c0a284bef-0-3" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">dep</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M740.0,266.5 L748.0,254.5 732.0,254.5" fill="currentColor"/>
# </g>
# </svg></span>
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="6af0ebaf4dec4356993a333e1b30fb54-0" class="displacy" width="750" height="312.0" direction="ltr" style="max-width: none; height: 312.0px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="222.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">November</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="222.0">
#     <tspan class="displacy-word" fill="currentColor" x="225">23,</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="225">NUM</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="222.0">
#     <tspan class="displacy-word" fill="currentColor" x="400">2021</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="400">NUM</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="222.0">
#     <tspan class="displacy-word" fill="currentColor" x="575">
# </tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="575">SPACE</tspan>
# </text>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-6af0ebaf4dec4356993a333e1b30fb54-0-0" stroke-width="2px" d="M70,177.0 C70,89.5 220.0,89.5 220.0,177.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-6af0ebaf4dec4356993a333e1b30fb54-0-0" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">nummod</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M220.0,179.0 L228.0,167.0 212.0,167.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-6af0ebaf4dec4356993a333e1b30fb54-0-1" stroke-width="2px" d="M70,177.0 C70,2.0 400.0,2.0 400.0,177.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-6af0ebaf4dec4356993a333e1b30fb54-0-1" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">nummod</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M400.0,179.0 L408.0,167.0 392.0,167.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-6af0ebaf4dec4356993a333e1b30fb54-0-2" stroke-width="2px" d="M420,177.0 C420,89.5 570.0,89.5 570.0,177.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-6af0ebaf4dec4356993a333e1b30fb54-0-2" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">dep</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M570.0,179.0 L578.0,167.0 562.0,167.0" fill="currentColor"/>
# </g>
# </svg></span>
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="1dc91aa79a8a41fca9df61071ccb925d-0" class="displacy" width="14225" height="574.5" direction="ltr" style="max-width: none; height: 574.5px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="50">The</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="225">digital</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="225">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="400">revolution</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="400">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="575">forced</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="575">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="750">every</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="750">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="925">organization</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="925">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="1100">to</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1100">PART</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="1275">reinvent</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1275">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="1450">itself,</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1450">PRON</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="1625">or</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1625">CCONJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="1800">at</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1800">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="1975">least</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1975">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="2150">rethink</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2150">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="2325">how</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2325">SCONJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="2500">it</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2500">PRON</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="2675">goes</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2675">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="2850">about</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2850">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="3025">doing</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3025">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="3200">business.</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3200">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="3375">Most</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3375">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="3550">large</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3550">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="3725">companies</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3725">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="3900">have</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3900">AUX</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="4075">invested</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4075">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="4250">substantial</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4250">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="4425">cash</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4425">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="4600">in</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4600">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="4775">what</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4775">PRON</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="4950">is</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4950">AUX</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="5125">generally</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="5125">ADV</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="5300">labelled “</tspan>
#     <tspan class="displacy-tag" dy
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="eb39aa2c1f38484c885038c3c6b35e57-0" class="displacy" width="25250" height="749.5" direction="ltr" style="max-width: none; height: 749.5px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="659.5">
#     <tspan class="displacy-word" fill="currentColor" x="50">For</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="659.5">
#     <tspan class="displacy-word" fill="currentColor" x="225">example,</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="225">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="659.5">
#     <tspan class="displacy-word" fill="currentColor" x="400">common</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="400">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="659.5">
#     <tspan class="displacy-word" fill="currentColor" x="575">errors</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="575">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="659.5">
#     <tspan class="displacy-word" fill="currentColor" x="750">include</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="750">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="659.5">
#     <tspan class="displacy-word" fill="currentColor" x="925">the</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="925">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="659.5">
#     <tspan class="displacy-word" fill="currentColor" x="1100">naïve</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1100">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="659.5">
#     <tspan class="displacy-word" fill="currentColor" x="1275">assumption</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1275">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="659.5">
#     <tspan class="displacy-word" fill="currentColor" x="1450">that</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1450">SCONJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="659.5">
#     <tspan class="displacy-word" fill="currentColor" x="1625">by</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1625">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="659.5">
#     <tspan class="displacy-word" fill="currentColor" x="1800">simply</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1800">ADV</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="659.5">
#     <tspan class="displacy-word" fill="currentColor" x="1975">buying</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1975">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="659.5">
#     <tspan class="displacy-word" fill="currentColor" x="2150">technology —</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2150">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="659.5">
#     <tspan class="displacy-word" fill="currentColor" x="2325">or</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2325">CCONJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="659.5">
#     <tspan class="displacy-word" fill="currentColor" x="2500">investing</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2500">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="659.5">
#     <tspan class="displacy-word" fill="currentColor" x="2675">in</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2675">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="659.5">
#     <tspan class="displacy-word" fill="currentColor" x="2850">any</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2850">PRON</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="659.5">
#     <tspan class="displacy-word" fill="currentColor" x="3025">of</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3025">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="659.5">
#     <tspan class="displacy-word" fill="currentColor" x="3200">the</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3200">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="659.5">
#     <tspan class="displacy-word" fill="currentColor" x="3375">fancy</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3375">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="659.5">
#     <tspan class="displacy-word" fill="currentColor" x="3550">tools</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3550">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="659.5">
#     <tspan class="displacy-word" fill="currentColor" x="3725">or</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3725">CCONJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="659.5">
#     <tspan class="displacy-word" fill="currentColor" x="3900">shiny</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3900">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="659.5">
#     <tspan class="displacy-word" fill="currentColor" x="4075">new</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4075">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="659.5">
#     <tspan class="displacy-word" fill="currentColor" x="4250">objects</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4250">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="659.5">
#     <tspan class="displacy-word" fill="currentColor" x="4425">of</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4425">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="659.5">
#     <tspan class="displacy-word" fill="currentColor" x="4600">the</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4600">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="659.5">
#     <tspan class="displacy-word" fill="currentColor" x="4775">booming</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4775">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="659.5">
#     <tspan class="displacy-word" fill="currentColor" x="4950">tech</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4950">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="659.5">
#     <tspan class="displacy-word" fill="currentColor" x="5125">market —</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="5125">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="659.5">
#     <tspan class="displacy-word" fill="currentColor" x="5300">organizations</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="c
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="76e8cb875e6b4b85bd3c99521877ee0a-0" class="displacy" width="24375" height="749.5" direction="ltr" style="max-width: none; height: 749.5px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="659.5">
#     <tspan class="displacy-word" fill="currentColor" x="50">It</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">PRON</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="659.5">
#     <tspan class="displacy-word" fill="currentColor" x="225">’s</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="225">AUX</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="659.5">
#     <tspan class="displacy-word" fill="currentColor" x="400">problematic</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="400">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="659.5">
#     <tspan class="displacy-word" fill="currentColor" x="575">when</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="575">SCONJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="659.5">
#     <tspan class="displacy-word" fill="currentColor" x="750">companies</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="750">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="659.5">
#     <tspan class="displacy-word" fill="currentColor" x="925">decide</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="925">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="659.5">
#     <tspan class="displacy-word" fill="currentColor" x="1100">to</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1100">PART</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="659.5">
#     <tspan class="displacy-word" fill="currentColor" x="1275">embark</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1275">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="659.5">
#     <tspan class="displacy-word" fill="currentColor" x="1450">on</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1450">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="659.5">
#     <tspan class="displacy-word" fill="currentColor" x="1625">a</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1625">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="659.5">
#     <tspan class="displacy-word" fill="currentColor" x="1800">digital</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1800">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="659.5">
#     <tspan class="displacy-word" fill="currentColor" x="1975">transformation</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1975">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="659.5">
#     <tspan class="displacy-word" fill="currentColor" x="2150">agenda</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2150">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="659.5">
#     <tspan class="displacy-word" fill="currentColor" x="2325">without</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2325">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="659.5">
#     <tspan class="displacy-word" fill="currentColor" x="2500">having</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2500">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="659.5">
#     <tspan class="displacy-word" fill="currentColor" x="2675">a</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2675">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="659.5">
#     <tspan class="displacy-word" fill="currentColor" x="2850">clear</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2850">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="659.5">
#     <tspan class="displacy-word" fill="currentColor" x="3025">definition,</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3025">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="659.5">
#     <tspan class="displacy-word" fill="currentColor" x="3200">let</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3200">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="659.5">
#     <tspan class="displacy-word" fill="currentColor" x="3375">alone</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3375">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="659.5">
#     <tspan class="displacy-word" fill="currentColor" x="3550">vision,</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3550">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="659.5">
#     <tspan class="displacy-word" fill="currentColor" x="3725">for</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3725">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="659.5">
#     <tspan class="displacy-word" fill="currentColor" x="3900">what</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3900">PRON</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="659.5">
#     <tspan class="displacy-word" fill="currentColor" x="4075">it</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4075">PRON</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="659.5">
#     <tspan class="displacy-word" fill="currentColor" x="4250">means.</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4250">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="659.5">
#     <tspan class="displacy-word" fill="currentColor" x="4425">Although</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4425">SCONJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="659.5">
#     <tspan class="displacy-word" fill="currentColor" x="4600">every</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4600">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="659.5">
#     <tspan class="displacy-word" fill="currentColor" x="4775">organization</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4775">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="659.5">
#     <tspan class="displacy-word" fill="currentColor" x="4950">is</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4950">AUX</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="659.5">
#     <tspan class="displacy-word" fill="currentColor" x="5125">unique,</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="5125">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="659.5">
#     <tspan class="displacy-word" fill="currentColor" x="5300">and</tspan>
#     <tspan class="displacy-tag" dy="2em"
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="984f3fffeaa246baba3065ef061ef0b3-0" class="displacy" width="32425" height="662.0" direction="ltr" style="max-width: none; height: 662.0px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">In</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="225">short,</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="225">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="400">the</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="400">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="575">critical</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="575">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="750">part</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="750">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="925">of</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="925">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="1100">digital</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1100">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="1275">transformation</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1275">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="1450">is</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1450">AUX</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="1625">not “</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1625">PART</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="1800">digital”</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1800">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="1975">but “</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1975">CCONJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="2150">transformation.”</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2150">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="2325">Our</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2325">PRON</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="2500">world</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2500">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="2675">has</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2675">AUX</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="2850">changed</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2850">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="3025">dramatically</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3025">ADV</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="3200">in</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3200">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="3375">the</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3375">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="3550">past</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3550">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="3725">two</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3725">NUM</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="3900">decades,</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3900">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="4075">and</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4075">CCONJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="4250">adapting</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4250">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="4425">your</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4425">PRON</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="4600">organization</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4600">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="4775">to</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4775">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="4950">these</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4950">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="5125">changes</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="5125">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="5300">can</tspan>
#     <tspan class="displacy-tag" dy="2
# [('The Essential Components of Digital Revolution', 'ORG')]
# [('Tomas Chamorro-Premuzic', 'PERSON')]
# [('November 23, 2021', 'DATE')]
# [('$6.8 trillion', 'MONEY'), ('2023', 'DATE')]
# [('Stanford', 'ORG'), ('Erik Brynjolfsson', 'PERSON'), ('AI', 'ORG')]
# [('Google', 'ORG'), ('Amazon', 'ORG')]
# [('the past two decades', 'DATE'), ('overnight', 'TIME'), ('one', 'CARDINAL'), ('today', 'DATE')]

# %%
# Generate the tokens for each doc container and save the token features to a Dataframe.

import pandas as pd

df = pd.DataFrame()


for doc in documents:
    token_details=[]
    for token in doc:
        token_details.append([token.text, token.lemma_, token.pos_, token.tag_, token.dep_,
            token.shape_, token.is_alpha, token.is_stop, token.morph, token.morph.get("PronType"), token.head.text, token.head.pos_,
            [child for child in token.children]])

        df_doc = pd.DataFrame(token_details, columns=["text", "lemma_", "pos_", "tag_", "dep_", "shape", "is_alpha", "is_stop", "morph", "PronType", "Head text", "Head pos_", "Children"])
    df = df.append(df_doc)

df.to_csv("tokenFeatures.csv")
# Out:
# /tmp/ipykernel_43679/1051398071.py:16: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(df_doc)
# /tmp/ipykernel_43679/1051398071.py:16: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(df_doc)
# /tmp/ipykernel_43679/1051398071.py:16: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(df_doc)
# /tmp/ipykernel_43679/1051398071.py:16: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(df_doc)
# /tmp/ipykernel_43679/1051398071.py:16: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(df_doc)
# /tmp/ipykernel_43679/1051398071.py:16: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(df_doc)
# /tmp/ipykernel_43679/1051398071.py:16: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(df_doc)

# %%
# Generate the first 10 dimensions of text embeddings for the tokens in the document

words = df["text"]

text_embeddings = []
for w in words:
    word_vector = []
    if lg_nlp.vocab.has_vector(w):
        word_vector.append(w)
        word_vector.append(lg_nlp.vocab.get_vector(w)[:10])
        
    text_embeddings.append(word_vector)

df = pd.DataFrame(text_embeddings, columns=["text", "10embeddings"])
print(df)
df.to_csv("tokenEmbeddings.csv", index=False)
# Out:
#            text                                       10embeddings
# 0           The  [-7.2681, -0.85717, 5.8105, 1.9771, 8.8147, -5...
# 1     Essential  [-0.74241, -1.4054, 0.53299, 2.3219, 4.1204, -...
# 2    Components  [-1.5052, -3.0381, 0.99777, 5.6067, 4.3485, 1....
# 3            of  [-12.667, -6.568, -0.61537, 4.9492, 22.389, 2....
# 4       Digital  [-0.5775, -1.2313, 4.2546, 1.8479, 0.79478, -2...
# ..          ...                                                ...
# 637       today  [1.5333, 1.6226, 1.0552, -1.3615, 0.97952, -0....
# 638          ’s  [9.4848, 8.2625, -3.5644, -8.9888, 10.483, 5.4...
# 639      bridge  [-3.5745, 3.8444, 1.601, -2.8568, 2.0489, 0.70...
# 640           .  [-0.076454, -4.6896, -4.0431, -3.4333, 11.758,...
# 641        None                                               None
#
# [642 rows x 2 columns]

# %%
# Create a Doc container for each query_document
query1 = "The introduction of new technologies has revolutionized the way people do business"
query2 = "Digital revolution in reality, is aimed to increase the return on investment for small and large businesses"
query3 = "Digital revolution is a new paradigm and provides data-driven approach to understand the trends and gather new insights for better decision making"

results = []
queries = [query1, query2, query3]
for query in queries:
    results.append(lg_nlp(query))

# Print similarity scores of each Doc container and the phrase document
for i, doc in enumerate(results):
  print(f"Semantic similarity with document {i+1}:", round(doc.similarity(documents[0]), 3))

# the text appears to be pretty relavant to what is contained in the doc
# Out:
# Semantic similarity with document 1: 0.723
# Semantic similarity with document 2: 0.653
# Semantic similarity with document 3: 0.633
